# %%
import pandas as pd
import numpy as np
from pathlib import Path
import datetime

# %%
full_df=Path("features.csv")
full_df=pd.read_csv(full_df,infer_datetime_format=True,parse_dates=True,index_col="DATE")

# %%
full_df
# Out:
#             y_monthly_retail  gas_prices  consumer_sentiments  \
# DATE
# 1992-01-01          146925.0     1.02200                 67.5
# 1992-02-01          147223.0     1.00600                 68.8
# 1992-03-01          146805.0     1.01260                 76.0
# 1992-04-01          148032.0     1.05175                 77.2
# 1992-05-01          149010.0     1.10725                 79.2
# 1992-06-01          149800.0     1.14480                 80.4
# 1992-07-01          150761.0     1.13650                 76.6
# 1992-08-01          151067.0     1.12180                 76.1
# 1992-09-01          152588.0     1.12150                 75.6
# 1992-10-01          153521.0     1.11400                 73.3
# 1992-11-01          153583.0     1.11120                 85.3
# 1992-12-01          155614.0     1.07750                 91.0
# 1993-01-01          157555.0     1.06175                 89.3
# 1993-02-01          156266.0     1.05425                 86.6
# ...
