# %%
import os
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import ccxt
import bitfinex
import datetime
import time
import alpaca_trade_api as tradeapi

# %%
load_dotenv()
# Out:
# True

# %%
alpaca_api_key=os.getenv("ALPACA_API_KEY")

# %%
alpaca_secret_key=os.getenv("ALPACA_SECRET_KEY")

# %%
api=tradeapi.REST(alpaca_api_key,alpaca_secret_key,api_version='v2')

# %%
api

# %%
index_df=pd.DataFrame()

# %%
ticker="SPY"

# %%
timeframe='1M'

# %%
start_date=pd.Timestamp("2")

# %%
public_key=os.getenv("BIT_FIN")

# %%
api_v2 = bitfinex.bitfinex_v2.api_v2()
# Out:
# No keys, only access to public API functions

# %%
load_dotenv()
# Out:
# True

# %%
def fetch_data():
    """Fetches the latest prices."""
    bitfinex_public = os.getenv("KRAKEN_PUBLIC_KEY")
    bitfinex_secret_key = os.getenv("KRAKEN_SECRET_KEY")
    bitfinex = ccxt.bitfinex({"apiKey": kraken_public_key, "secret": kraken_secret_key})

    close = bifinex.fetch_ticker("BTC/USD")["close"]
    datetime = kraken.fetch_ticker("BTC/USD")["datetime"]
    df = pd.DataFrame({"close": [close]})
    df.index = pd.to_datetime([datetime])
    return df

# %%
pair='xauusd'
bin_size="1M"
limit=1000

# %%
t_start=datetime.datetime(1992,11,1,0,0)
t_start=time.mktime(t_start.timetuple())*1000

# %%
t_stop=datetime.datetime(2020,10,1,0,0)
t_stop=time.mktime(t_stop.timetuple())*1000

# %%
result=api_v2.candles(symbol=pair,interval=bin_size,limit=limit,start=t_start,end=t_stop)

# %%
result
# Out:
# []

# %%
result=api_v2.candles()

# %%
result
# Out:
# [[1602891420000,
#   11356.47868618,
#   11356.59585024,
#   11356.59585024,
#   11356.47868618,
#   0.01],
#  [1602891360000,
#   11356.59585024,
#   11356.5389481,
#   11356.59585024,
#   11356.5389481,
#   0.015],
#  [1602891300000, 11351, 11356.94734244, 11357, 11351, 0.9673989399999999],
#  [1602891240000, 11346, 11350, 11350, 11346, 0.051680130000000005],
#  [1602891180000, 11345, 11345, 11345, 11345, 0.01],
#  [1602891120000, 11344, 11344, 11344, 11344, 0.01],
#  [1602891060000, 11343, 11343, 11343, 11342.65332627, 0.27560557],
#  [1602891000000,
#   11342.65332627,
#   11342.5361622,
#   11342.65332627,
#   11342.5361622,
#   0.02],
#  [1602890940000, 11339, 11341.24735747, 11342, 11339, 0.14905876],
#  [1602890880000, 11338.07051111, 11338.29145, 11339, 11338.00452526, 0.035814],
#  [1602890820000, 11343, 11334.06686393, 11343, 11333, 1.8813],
#  [1602890760000, 11354, 11343, 11354, 11343, 0.51469818],
#  [1602890700000, 11354, 11354, 11354.05406567, 11354, 0.010213],
# ...
