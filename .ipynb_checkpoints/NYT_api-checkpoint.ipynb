# %%
import os
import pandas as pd
from dotenv import load_dotenv
from nytimesarticle import articleAPI
load_dotenv()
# Out:
# True

# %%
nyt_api_key = os.getenv("NYT_API")

api= articleAPI(nyt_api_key)

api

# %%
articles_92 = api.search(q="holiday sales",begin_date=19921101, end_date=19921231)
articles_92
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': "  It was a hair-raising holiday season for many of the nation's retailers: sales started out strong, dropped off precipitously and finally skyrocketed the last weekend before Christmas.   Most merchants say their holiday business improved this year despite the ups and downs caused by unusually nasty weather and news of more layoffs and revampings among America's blue-chip companies.",
#     'web_url': 'https://www.nytimes.com/1992/12/26/business/a-sharp-rebound-in-christmas-sales.html',
#     'snippet': '',
#     'lead_paragraph': "It was a hair-raising holiday season for many of the nation's retailers: sales started out strong, dropped off precipitously and finally skyrocketed the last weekend before Christmas.",
#     'print_section': '1',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A SHARP REBOUND IN CHRISTMAS SALES',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A SHARP REBOUND IN CHRISTMAS SALES',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Weather',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'}],
#     'pub_date': '1992-12-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/aed39531-cf52-5e78-bdcd-f1c2f5f56fdf',
#     'word_count': 1314,
#     'uri': 'nyt://article/aed39531-cf52-5e78-bdcd-f1c2f5f56fdf'},
#    {'abstract': "  A Blow to the Wallet   Retailers and public officials lamented the storm's temporary effect on holiday sales and feared the costly, prolonged work needed to repair ravaged beaches and homes. Page 49. Transit's Fragile System   The breakdown of New York's subways during the storm underscored its reliance on a rare electric current to run many safety signals. Page 55.",
#     'web_url': 'https://www.nytimes.com/1992/12/13/nyregion/more-on-the-storm.html',
#     'snippet': '',
#     'lead_paragraph': 'A Blow to the Wallet',
#     'print_section': '1',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'MORE ON THE STORM',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'MORE ON THE STORM',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'NO INDEX TERMS',
#       'rank': 1,
#       'major': 'N'}],
#     'pub_date': '1992-12-13T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Metropolitan Desk',
#     'section_name': 'New York',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/73a06b30-ef2e-575d-b61e-bdad7fdefdbf',
#     'word_count': 63,
#     'uri': 'nyt://article/73a06b30-ef2e-575d-b61e-bdad7fdefdbf'},
#    {'abstract': '  Signs of a comeback in consumer spending pushed the broad stock market averages to record highs yesterday, although trading volume was the lightest of the year.   The Dow Jones industrial average rose 15.94 points, to 3,282.20, ending a holiday-shortened week with a solid gain of 54.84 points.',
#     'web_url': 'https://www.nytimes.com/1992/11/28/business/stocks-hit-record-highs-on-slow-day.html',
#     'snippet': '',
#     'lead_paragraph': 'Signs of a comeback in consumer spending pushed the broad stock market averages to record highs yesterday, although trading volume was the lightest of the year.',
#     'print_section': '1',
#     'print_page': '33',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Stocks Hit Record Highs On Slow Day',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Stocks Hit Record Highs On Slow Day',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'New York Stock Exchange',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Records and Achievements',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Nasdaq Composite Index',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Stocks and Bonds', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Dow Jones Stock Average',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'STOCK PRICES AND TRADING VOLUME',
#       'rank': 6,
#       'major': 'N'}],
#     'pub_date': '1992-11-28T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/698cb309-543f-5958-8a2c-9c2a3186d6aa',
#     'word_count': 585,
#     'uri': 'nyt://article/698cb309-543f-5958-8a2c-9c2a3186d6aa'},
#    {'abstract': '  Losses at R. H. Macy & Company narrowed in the first quarter of its 1993 fiscal year, the bankrupt retailer reported yesterday. It added that holiday sales were running ahead of last year and slightly ahead of plan, but the company said it remained cautious.   For the quarter that ended on Oct. 31, Macy reported a loss of $135.8 million on sales of $1.5 billion, compared with a loss of $155.3 million on sales of $1.6 billion in the corresponding period a year ago. The first quarter of 1992 included sales at stores that have since been closed.',
#     'web_url': 'https://www.nytimes.com/1992/12/12/business/macy-reports-a-narrower-loss-in-quarter.html',
#     'snippet': '',
#     'lead_paragraph': 'Losses at R. H. Macy & Company narrowed in the first quarter of its 1993 fiscal year, the bankrupt retailer reported yesterday. It added that holiday sales were running ahead of last year and slightly ahead of plan, but the company said it remained cautious.',
#     'print_section': '1',
#     'print_page': '39',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Macy Reports a Narrower Loss in Quarter',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Macy Reports a Narrower Loss in Quarter',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Macy, R H, & Co Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Company Reports', 'rank': 2, 'major': 'N'}],
#     'pub_date': '1992-12-12T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Kenneth N. Gilpin',
#      'person': [{'firstname': 'Kenneth',
#        'middlename': 'N.',
#        'lastname': 'Gilpin',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/00a874c7-8489-50e2-b700-85ebae13f817',
#     'word_count': 530,
#     'uri': 'nyt://article/00a874c7-8489-50e2-b700-85ebae13f817'},
#    {'abstract': "  With their fingers tightly crossed and rabbits' feet stashed in their pockets, merchants are predicting healthy -- but not robust -- sales increases this holiday season.   Retailers are taking hope from their strong performances in the third quarter, when sales and profits increased for many. Also figuring into their estimates are the recent encouraging economic statistics, like stronger housing starts, rising consumer confidence and slightly lower unemployment and consumer debt loads.",
#     'web_url': 'https://www.nytimes.com/1992/11/19/business/a-retail-season-of-hope-and-caution.html',
#     'snippet': '',
#     'lead_paragraph': "With their fingers tightly crossed and rabbits' feet stashed in their pockets, merchants are predicting healthy -- but not robust -- sales increases this holiday season.",
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A Retail Season of Hope and Caution',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A Retail Season of Hope and Caution',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'United States',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Forecasts', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Holidays and Special Occasions',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 5, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'PROFITS (INDUSTRY-WIDE)',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 7,
#       'major': 'N'}],
#     'pub_date': '1992-11-19T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/eb2c970a-735a-5af3-b217-2d0ff69ba02c',
#     'word_count': 1170,
#     'uri': 'nyt://article/eb2c970a-735a-5af3-b217-2d0ff69ba02c'},
#    {'abstract': '  The Kmart Corporation, the discount and specialty store chain, reported yesterday that a program of renovating and enlarging its discount stores paid off in increases of about 12 percent in profits and sales in its third quarter.   And Toys "R" Us Inc., the specialty toy retailer, said strong sales at its stores in Europe and Japan and its Kids "R" Us apparel chain helped lift profits nearly 15 percent while sales rose more than 14 percent in the quarter.',
#     'web_url': 'https://www.nytimes.com/1992/11/17/business/company-news-2-retailers-post-gains-in-earnings.html',
#     'snippet': '',
#     'lead_paragraph': 'The Kmart Corporation, the discount and specialty store chain, reported yesterday that a program of renovating and enlarging its discount stores paid off in increases of about 12 percent in profits and sales in its third quarter.',
#     'print_section': 'D',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': '2 Retailers Post Gains In Earnings',
#      'kicker': 'COMPANY NEWS',
#      'content_kicker': None,
#      'print_headline': 'COMPANY NEWS; 2 Retailers Post Gains In Earnings',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': "Toys 'R' Us Inc",
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations', 'value': 'Kmart Corp', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Company Reports', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1992-11-17T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/8ac89f34-1afd-50de-801e-e5ef7abe2b5a',
#     'word_count': 520,
#     'uri': 'nyt://article/8ac89f34-1afd-50de-801e-e5ef7abe2b5a'},
#    {'abstract': '   The Economy    The economy is staggering out of the recession, but people who are getting jobs again tell a sobering story. The good jobs of the past, with strong wages and benefits, are largely giving way to unstable and mediocre positions. That makes this recovery different from any other. And with corporate giants like G. M. and I.B.M. planning to shed tens of thousands of workers next year, the resilience of the recovery is in some doubt.  [ Page 1. ]   Most merchants\' holiday business improved this year despite ups and downs caused by unusually nasty weather and more layoffs and revampings among top companies. "People have shopped this year like there really is a Christmas," an analyst said. While retailers will not post holiday sales numbers until Thursday, a few experts estimate sales grew 8 or 9 percent from a year ago.  [ 1. ]',
#     'web_url': 'https://www.nytimes.com/1992/12/26/business/business-digest-011492.html',
#     'snippet': '',
#     'lead_paragraph': 'The Economy',
#     'print_section': '1',
#     'print_page': '37',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'BUSINESS DIGEST',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'BUSINESS DIGEST',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'creative_works',
#       'value': 'BUSINESS DIGEST (NYT)',
#       'rank': 1,
#       'major': 'N'}],
#     'pub_date': '1992-12-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/a6e7f08c-213f-5163-927a-3c0f646bbeeb',
#     'word_count': 678,
#     'uri': 'nyt://article/a6e7f08c-213f-5163-927a-3c0f646bbeeb'},
#    {'abstract': '  The economy is improving modestly but unevenly across the country, with retailers expressing optimism about the holiday season, the Federal Reserve said today.   In its periodic assessment of the state of the economy, the central bank said almost all regions were experiencing "a slight to moderate pickup in some or all sectors of the economy" while noting specifically that California was doing worse than other states.',
#     'web_url': 'https://www.nytimes.com/1992/12/10/business/fed-survey-finds-an-upturn-but-an-uneven-one.html',
#     'snippet': '',
#     'lead_paragraph': 'The economy is improving modestly but unevenly across the country, with retailers expressing optimism about the holiday season, the Federal Reserve said today.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Fed Survey Finds an Upturn, but an Uneven One',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Fed Survey Finds an Upturn, but an Uneven One',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'California',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Federal Reserve System',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Economic Conditions and Trends',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1992-12-10T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Steven Greenhouse',
#      'person': [{'firstname': 'Steven',
#        'middlename': None,
#        'lastname': 'Greenhouse',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/0b017c13-1f89-5910-b2a9-b53f3f21b773',
#     'word_count': 723,
#     'uri': 'nyt://article/0b017c13-1f89-5910-b2a9-b53f3f21b773'},
#    {'abstract': "  The Economy    Retail sales rose for the fifth straight month in November, while consumer prices rose a modest 0.2 percent. Last month's sales rise was 0.4 percent, but this was after October's gain of 0.9 percent was revised upward to 1.9 percent.  [ Page 39. ]   Increasing taxes on the rich will not raise as much revenue as the Clinton economic team has projected, both because the rich can take steps to avoid taxes and because they may not possess as many riches as they used to.  [ 39. ]",
#     'web_url': 'https://www.nytimes.com/1992/12/12/business/business-digest-751692.html',
#     'snippet': '',
#     'lead_paragraph': 'The Economy',
#     'print_section': '1',
#     'print_page': '39',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'BUSINESS DIGEST',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'BUSINESS DIGEST',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'NO INDEX TERMS',
#       'rank': 1,
#       'major': 'N'}],
#     'pub_date': '1992-12-12T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/b35b462e-4eed-5210-a5d7-cf3c04a4fe01',
#     'word_count': 607,
#     'uri': 'nyt://article/b35b462e-4eed-5210-a5d7-cf3c04a4fe01'},
#    {'abstract': 'THE good news is that consumer spending on Long Island rose for the fifth month in a row, thanks to brisk holiday sales and a rise in consumer confidence. The bad news is that much of the seasonal spree was financed on plastic. \n\nA result: Thousands of overzealous holiday spenders will usher in the new year with painful debt hangovers.',
#     'web_url': 'https://www.nytimes.com/1992/12/27/nyregion/with-the-holiday-more-debt-woes.html',
#     'snippet': 'THE good news is that consumer spending on Long Island rose for the fifth month in a row, thanks to brisk holiday sales and a rise in consumer confidence. The bad news is that much of the seasonal spree was financed on plastic. \n\nA result: Thousan...',
#     'lead_paragraph': 'THE good news is that consumer spending on Long Island rose for the fifth month in a row, thanks to brisk holiday sales and a rise in consumer confidence. The bad news is that much of the seasonal spree was financed on plastic. ',
#     'print_section': '13LI',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'With the Holiday, More Debt Woes',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'With the Holiday, More Debt Woes',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'Long Island (NY)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'CASSAMASSIMA, CHRISTY',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'CREDIT CARDS AND ACCOUNTS',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Consumer Behavior',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Interest Rates', 'rank': 6, 'major': 'N'},
#      {'name': 'subject', 'value': 'CONSUMER CREDIT', 'rank': 7, 'major': 'N'}],
#     'pub_date': '1992-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Long Island Weekly Desk',
#     'section_name': 'New York',
#     'subsection_name': 'Long Island',
#     'byline': {'original': 'By Christy Cassamassima',
#      'person': [{'firstname': 'Christy',
#        'middlename': None,
#        'lastname': 'Cassamassima',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/f73a7217-e983-5672-b796-45b6ea218987',
#     'word_count': 1726,
#     'uri': 'nyt://article/f73a7217-e983-5672-b796-45b6ea218987'}],
#   'meta': {'hits': 15, 'offset': 0, 'time': 87}}}

# %%
articles_93 = api.search(q="holiday sales",begin_date=19931101, end_date=19931231)
articles_94 = api.search(q="holiday sales",begin_date=19941101, end_date=19941231)
articles_95 = api.search(q="holiday sales",begin_date=19951101, end_date=19951231)
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': '  When the nation\'s retailers locked their doors Friday evening after a 29-day holiday season that began the day after Thanksgiving, many were relieved that a late surge of shopping would produce modestly respectable sales figures.   "It was explosive the last few days before Christmas," said Walter F. Loeb, a consultant in New York who works with leading retailers. "Customers were rushing to the stores."',
#     'web_url': 'https://www.nytimes.com/1993/12/27/business/late-sales-lift-results-for-stores.html',
#     'snippet': '',
#     'lead_paragraph': "When the nation's retailers locked their doors Friday evening after a 29-day holiday season that began the day after Thanksgiving, many were relieved that a late surge of shopping would produce modestly respectable sales figures.",
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Late Sales Lift Results For Stores',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Late Sales Lift Results For Stores',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'}],
#     'pub_date': '1993-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Joshua Mills',
#      'person': [{'firstname': 'Joshua',
#        'middlename': None,
#        'lastname': 'Mills',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/efb58a82-820b-5055-971c-dbf8b84283b8',
#     'word_count': 941,
#     'uri': 'nyt://article/efb58a82-820b-5055-971c-dbf8b84283b8'},
#    {'abstract': '  There was little consistency in the October sales figures reported yesterday by most of the major retail chains, leaving merchants with few hints about how they will fare during the critical holiday sales season.   For every department store operator that had sluggish sales in October, there was one with healthy gains, a pattern that held true for most other types of retailers.',
#     'web_url': 'https://www.nytimes.com/1993/11/05/business/sales-data-offer-few-clues-to-stores-holiday-prospects.html',
#     'snippet': '',
#     'lead_paragraph': 'There was little consistency in the October sales figures reported yesterday by most of the major retail chains, leaving merchants with few hints about how they will fare during the critical holiday sales season.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Sales Data Offer Few Clues To Stores' Holiday Prospects",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Sales Data Offer Few Clues To Stores' Holiday Prospects",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'United States',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'}],
#     'pub_date': '1993-11-05T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/bd7727e7-0dcc-52c0-be69-9e46d9261275',
#     'word_count': 1072,
#     'uri': 'nyt://article/bd7727e7-0dcc-52c0-be69-9e46d9261275'},
#    {'abstract': '  Never mind that holly boughs, tinsel and blinking lights have festooned store windows and shopping malls since Halloween. Tomorrow, the annual holiday shopping season officially begins, the most profitable time of year for retailers. But there is little consensus about just how strong sales will be this year.   In the past, estimates of holiday sales have tended to converge as Thanksgiving approached. What started out as very different predictions in September following back-to-school sales usually ended up as very similar estimates as Christmas drew nearer and a herd mentality seized the financial community.',
#     'web_url': 'https://www.nytimes.com/1993/11/25/business/this-season-retail-experts-can-t-seem-to-agree.html',
#     'snippet': '',
#     'lead_paragraph': 'Never mind that holly boughs, tinsel and blinking lights have festooned store windows and shopping malls since Halloween. Tomorrow, the annual holiday shopping season officially begins, the most profitable time of year for retailers. But there is little consensus about just how strong sales will be this year.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "This Season, Retail Experts Can't Seem to Agree",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "This Season, Retail Experts Can't Seem to Agree",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'United States',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Forecasts', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '1993-11-25T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/397c82e8-c188-5a64-95d5-c51329d7fb5f',
#     'word_count': 1110,
#     'uri': 'nyt://article/397c82e8-c188-5a64-95d5-c51329d7fb5f'},
#    {'abstract': "  Although holiday sales have proved somewhat disappointing, what with cold weather and consumers' resolute resistance to anything but bargain-basement prices, disconsolate retailers can take heart.    The Appert Gift Wrap Indicator predicts that sales of nondurable goods will rise 4.9 percent in the fourth quarter, not as much as last year's jump, but stronger than recent sales would suggest.",
#     'web_url': 'https://www.nytimes.com/1993/12/13/business/gift-wrap-index-predicts-happy-holiday-for-retailers.html',
#     'snippet': '',
#     'lead_paragraph': "Although holiday sales have proved somewhat disappointing, what with cold weather and consumers' resolute resistance to anything but bargain-basement prices, disconsolate retailers can take heart.",
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Gift-Wrap Index Predicts Happy Holiday for Retailers',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Gift-Wrap Index Predicts Happy Holiday for Retailers',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'United States',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'APPERT GIFT WRAP INDICATOR',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'APPERT GIFT WRAP INDICATOR',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '1993-12-13T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/7a1ed1ff-4538-5ec1-9c28-571f4537d570',
#     'word_count': 301,
#     'uri': 'nyt://article/7a1ed1ff-4538-5ec1-9c28-571f4537d570'},
#    {'abstract': '  Reviews were upbeat yesterday for the traditional opening weekend of the holiday shopping season, but merchants refused to read too much into the sales data flooding into their laptop computers.   The 29 days between Thanksgiving and Christmas will be the most profitable time of year for many retail companies, but consumer spending during the first weekend is no longer considered a reliable barometer because shoppers now do the bulk of their holiday shopping in the final week of the season.',
#     'web_url': 'https://www.nytimes.com/1993/11/29/business/cheered-by-solid-weekend-sales-merchants-still-won-t-celebrate.html',
#     'snippet': '',
#     'lead_paragraph': 'Reviews were upbeat yesterday for the traditional opening weekend of the holiday shopping season, but merchants refused to read too much into the sales data flooding into their laptop computers.',
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Cheered by Solid Weekend Sales, Merchants Still Won't Celebrate",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Cheered by Solid Weekend Sales, Merchants Still Won't Celebrate",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'United States',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Weather', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '1993-11-29T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/885cd3d5-c714-56b4-b1ae-27354445feb3',
#     'word_count': 1188,
#     'uri': 'nyt://article/885cd3d5-c714-56b4-b1ae-27354445feb3'},
#    {'abstract': '  Shares of the Sharper Image Company surged 37 percent yesterday after the retailer, known for selling quirky gadgets and toys, said its holiday sales were beating its projections. "The season has been steadily improving as its draws to a close," Craig Womack, president of Sharper Image, said in a news release. Its stock closed up $1.375, to $5.125. "As long as January remains on plan, we expect to report a substantial earnings gain over last year, in the range of 200 percent to 300 percent," Mr. Womack said. The company sells merchandise in its 76 stores, in department stores, on television shopping programs and through its catalogue.',
#     'web_url': 'https://www.nytimes.com/1993/12/23/business/company-news-sharper-image-s-stock-surges-on-holiday-report.html',
#     'snippet': '',
#     'lead_paragraph': 'Shares of the Sharper Image Company surged 37 percent yesterday after the retailer, known for selling quirky gadgets and toys, said its holiday sales were beating its projections. "The season has been steadily improving as its draws to a close," Craig Womack, president of Sharper Image, said in a news release. Its stock closed up $1.375, to $5.125. "As long as January remains on plan, we expect to report a substantial earnings gain over last year, in the range of 200 percent to 300 percent," Mr. Womack said. The company sells merchandise in its 76 stores, in department stores, on television shopping programs and through its catalogue.',
#     'print_section': 'D',
#     'print_page': '3',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "SHARPER IMAGE'S STOCK SURGES ON HOLIDAY REPORT",
#      'kicker': 'COMPANY NEWS',
#      'content_kicker': None,
#      'print_headline': "COMPANY NEWS; SHARPER IMAGE'S STOCK SURGES ON HOLIDAY REPORT",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'SHARPER IMAGE CORP',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'STOCKS (CORPORATE)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'SHARPER IMAGE CORP SHARPER IMAGE CORP',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1993-12-23T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/4cbf3903-daa6-58b4-8413-4a7ecca5727b',
#     'word_count': 107,
#     'uri': 'nyt://article/4cbf3903-daa6-58b4-8413-4a7ecca5727b'},
#    {'abstract': '  Consumers are taking merchants on a roller coaster ride this holiday season, jamming to overflowing parking lots outside malls and strip centers one day, and staying home en masse the next.   So erratic has their business been that many retailers say they will not really know how they fared during their peak sales and profit period -- the weeks between Thanksgiving and Christmas -- until the proverbial fat lady sings, and they do not expect her to make a curtain call until Christmas Eve.',
#     'web_url': 'https://www.nytimes.com/1993/12/20/business/shoppers-are-fickle-this-holiday-season.html',
#     'snippet': '',
#     'lead_paragraph': 'Consumers are taking merchants on a roller coaster ride this holiday season, jamming to overflowing parking lots outside malls and strip centers one day, and staying home en masse the next.',
#     'print_section': 'D',
#     'print_page': '8',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Shoppers Are Fickle This Holiday Season',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Shoppers Are Fickle This Holiday Season',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'United States',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Consumer Behavior',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1993-12-20T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/6283f4c8-2c5c-55a0-aa7e-979d40b31805',
#     'word_count': 736,
#     'uri': 'nyt://article/6283f4c8-2c5c-55a0-aa7e-979d40b31805'},
#    {'abstract': '  R. H. Macy & Company reported yesterday that despite slipping sales volume, cash flow was markedly stronger in its first fiscal quarter, largely because of cuts in expenses.   Because of a change in accounting practices, Macy, which is operating under bankruptcy court protection from creditors, had earnings of $67.4 million in the quarter, in contrast to a loss of $135.9 million in the corresponding period last year. Without the accounting change, it would have posted a $117.9 million loss in the quarter that ended Oct. 30.',
#     'web_url': 'https://www.nytimes.com/1993/12/15/business/company-news-macy-says-cash-flow-was-better.html',
#     'snippet': '',
#     'lead_paragraph': 'R. H. Macy & Company reported yesterday that despite slipping sales volume, cash flow was markedly stronger in its first fiscal quarter, largely because of cuts in expenses.',
#     'print_section': 'D',
#     'print_page': '5',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Macy Says Cash Flow Was Better',
#      'kicker': 'COMPANY NEWS',
#      'content_kicker': None,
#      'print_headline': 'COMPANY NEWS; Macy Says Cash Flow Was Better',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Macy, R H, & Co Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'ULLMAN, MYRON E 3D',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Company Reports', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Bankruptcies', 'rank': 4, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'MACY, R H, & CO INC R H MACY & CO INC',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '1993-12-15T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/8cf24a0a-538e-529d-8766-ee2498581b8b',
#     'word_count': 432,
#     'uri': 'nyt://article/8cf24a0a-538e-529d-8766-ee2498581b8b'},
#    {'abstract': "  A bright red stamp in the middle of the cover of the latest J. Peterman catalogue entices last-minute shoppers with a promise that orders placed by noon on Dec. 23 will arrive in time for Christmas.   Wolferman's, a mail-order company that sells baked goods, has mailed a postcard guaranteeing customers delivery in time for Christmas.",
#     'web_url': 'https://www.nytimes.com/1993/12/10/business/a-downside-of-mail-order-mania.html',
#     'snippet': '',
#     'lead_paragraph': 'A bright red stamp in the middle of the cover of the latest J. Peterman catalogue entices last-minute shoppers with a promise that orders placed by noon on Dec. 23 will arrive in time for Christmas.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A Downside of Mail-Order Mania',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A Downside of Mail-Order Mania',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'DIRECT MARKETING',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'NEAL, MOLLIE', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Mail Order Companies',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'INDUSTRY PROFILES',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Holidays and Special Occasions',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'DIRECT MARKETING (MAGAZINE)',
#       'rank': 8,
#       'major': 'N'}],
#     'pub_date': '1993-12-10T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/a7bca8d2-e8cb-5219-b2e7-5768725729c3',
#     'word_count': 1048,
#     'uri': 'nyt://article/a7bca8d2-e8cb-5219-b2e7-5768725729c3'},
#    {'abstract': '  Business conditions in most of the country improved at a "slow to moderate" clip during September and October, but large pockets on both seaboards remained lackluster, an anecdotal survey of the Federal Reserve Board\'s 12 districts showed today.   The findings of the central bank, though noting renewed strength in motor vehicles and housing, struck much the same tone as two months ago when it also described national growth as "slow to moderate," and seemed less buoyant than implied by various recent statistics.',
#     'web_url': 'https://www.nytimes.com/1993/11/04/business/fed-reports-a-slow-to-moderate-improvement-in-business.html',
#     'snippet': '',
#     'lead_paragraph': 'Business conditions in most of the country improved at a "slow to moderate" clip during September and October, but large pockets on both seaboards remained lackluster, an anecdotal survey of the Federal Reserve Board\'s 12 districts showed today.',
#     'print_section': 'D',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Fed Reports a Slow to Moderate Improvement in Business',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Fed Reports a Slow to Moderate Improvement in Business',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Federal Reserve System',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 2,
#       'major': 'N'}],
#     'pub_date': '1993-11-04T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Robert D. Hershey Jr',
#      'person': [{'firstname': 'Robert',
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/3a610d9e-642c-5b73-9b47-ab73035ed85e',
#     'word_count': 760,
#     'uri': 'nyt://article/3a610d9e-642c-5b73-9b47-ab73035ed85e'}],
#   'meta': {'hits': 14, 'offset': 0, 'time': 93}}}

# %%
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': "RETAILERS and economic analysts said last week that sales for the holiday season on Long Island were running higher than last year, a sign of a continued growth in consumer confidence and of strenth in the region's service sector. \n\nStrong sales would benefit Nassau and Suffolk Counties, where 8.5 percent sales taxes, the highest in the state, reap a bounty from seasonal sales that account for one-fifth of yearly municipal sales-tax revenues. Each county receives half the tax, a 4.25 percent share.",
#     'web_url': 'https://www.nytimes.com/1994/12/18/nyregion/holiday-sales-reflect-rise-in-confidence.html',
#     'snippet': "RETAILERS and economic analysts said last week that sales for the holiday season on Long Island were running higher than last year, a sign of a continued growth in consumer confidence and of strenth in the region's service sector. \n\nStrong sales w...",
#     'lead_paragraph': "RETAILERS and economic analysts said last week that sales for the holiday season on Long Island were running higher than last year, a sign of a continued growth in consumer confidence and of strenth in the region's service sector. ",
#     'print_section': '13LI',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Holiday Sales Reflect Rise In Confidence',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Holiday Sales Reflect Rise In Confidence',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'Long Island (NY)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Rather, John', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'SHOPPING CENTERS',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '1994-12-18T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Long Island Weekly Desk',
#     'section_name': 'New York',
#     'subsection_name': 'Long Island',
#     'byline': {'original': 'By John Rather',
#      'person': [{'firstname': 'John',
#        'middlename': None,
#        'lastname': 'Rather',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/56b27849-80ac-59b0-b40d-5e2a22d1b4e8',
#     'word_count': 1469,
#     'uri': 'nyt://article/56b27849-80ac-59b0-b40d-5e2a22d1b4e8'},
#    {'abstract': '  Shares of Toys "R" Us Inc. fell 9 percent yesterday as analysts cut earnings estimates after the retailer reported lower-than-expected sales for the holiday season. Robert J. Schweich, an analyst with Wert heim Schroder & Company, said Toys "R" Us probably failed to achieve domestic sales growth of 4 percent in stores open more than a year. The retailer, based in Paramus, N.J., reported a 7.4 percent gain in such sales last year. In addition, Mr. Schweich said, profits in Europe might increase to $130 million to $140 million, compared with earlier projections of $150 million. Shares of Toys "R" Us fell $3, to $30.175, on the New York Stock Exchange.',
#     'web_url': 'https://www.nytimes.com/1994/12/29/business/company-news-toys-r-us-shares-fall-on-weak-holiday-sales.html',
#     'snippet': '',
#     'lead_paragraph': 'Shares of Toys "R" Us Inc. fell 9 percent yesterday as analysts cut earnings estimates after the retailer reported lower-than-expected sales for the holiday season. Robert J. Schweich, an analyst with Wert heim Schroder & Company, said Toys "R" Us probably failed to achieve domestic sales growth of 4 percent in stores open more than a year. The retailer, based in Paramus, N.J., reported a 7.4 percent gain in such sales last year. In addition, Mr. Schweich said, profits in Europe might increase to $130 million to $140 million, compared with earlier projections of $150 million. Shares of Toys "R" Us fell $3, to $30.175, on the New York Stock Exchange.',
#     'print_section': 'D',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "TOYS 'R' US SHARES FALL ON WEAK HOLIDAY SALES",
#      'kicker': 'COMPANY NEWS',
#      'content_kicker': None,
#      'print_headline': "COMPANY NEWS; TOYS 'R' US SHARES FALL ON WEAK HOLIDAY SALES",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': "Toys 'R' Us Inc",
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Company Reports', 'rank': 2, 'major': 'N'}],
#     'pub_date': '1994-12-29T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/70f79eef-19a3-56f5-bb63-d9675a08c220',
#     'word_count': 114,
#     'uri': 'nyt://article/70f79eef-19a3-56f5-bb63-d9675a08c220'},
#    {'abstract': "  Mother Nature seems determined to keep merchants guessing about their prospects for the all-important holiday sales season, which officially begins the day after Thanksgiving.   The nation's chain stores said unseasonally balmy weather in several parts of the country contributed to slowing sales in October, the same reason they gave for September's weak performance.",
#     'web_url': 'https://www.nytimes.com/1994/11/04/business/company-news-warm-weather-slowed-retail-sales-in-october.html',
#     'snippet': '',
#     'lead_paragraph': 'Mother Nature seems determined to keep merchants guessing about their prospects for the all-important holiday sales season, which officially begins the day after Thanksgiving.',
#     'print_section': 'D',
#     'print_page': '3',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Warm Weather Slowed Retail Sales in October',
#      'kicker': 'COMPANY NEWS',
#      'content_kicker': None,
#      'print_headline': 'COMPANY NEWS; Warm Weather Slowed Retail Sales in October',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Weather', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1994-11-04T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/44d6533a-4f64-58fb-b56f-5263bad6da16',
#     'word_count': 1122,
#     'uri': 'nyt://article/44d6533a-4f64-58fb-b56f-5263bad6da16'},
#    {'abstract': '  Even as retailers take final markdowns as they prepare to bring in new merchandise, they worry that 1995 is shaping up as a difficult year.   The holiday selling season, which ended with a whimper on Saturday, was softer than many anticipated. And many merchants expect shoppers to suffer holiday hangovers nonetheless, when they begin receiving credit card bills next month.',
#     'web_url': 'https://www.nytimes.com/1994/12/28/business/merchants-fear-fewer-sales-ahead.html',
#     'snippet': '',
#     'lead_paragraph': 'Even as retailers take final markdowns as they prepare to bring in new merchandise, they worry that 1995 is shaping up as a difficult year.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Merchants Fear Fewer Sales Ahead',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Merchants Fear Fewer Sales Ahead',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Credit', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1994-12-28T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/99e54ed4-78b9-5eed-9278-5e8b96ec81e6',
#     'word_count': 728,
#     'uri': 'nyt://article/99e54ed4-78b9-5eed-9278-5e8b96ec81e6'},
#    {'abstract': "  The nation's retail chains managed to ring up moderate sales gains in November, but only after jump-starting their businesses with holiday-related promotions.   The month was a cliffhanger for most retailers as sales, which were weak in September and October, stalled during the first three weeks of the month before picking up steam around Thanksgiving Day.",
#     'web_url': 'https://www.nytimes.com/1994/12/02/business/retail-sales-rise-slowly-as-holiday-buying-begins.html',
#     'snippet': '',
#     'lead_paragraph': "The nation's retail chains managed to ring up moderate sales gains in November, but only after jump-starting their businesses with holiday-related promotions.",
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Retail Sales Rise Slowly As Holiday Buying Begins',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Retail Sales Rise Slowly As Holiday Buying Begins',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 2,
#       'major': 'N'}],
#     'pub_date': '1994-12-02T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/97c5d6d9-e24d-53f2-8d27-544bbdf69670',
#     'word_count': 1112,
#     'uri': 'nyt://article/97c5d6d9-e24d-53f2-8d27-544bbdf69670'},
#    {'abstract': 'HOLIDAY SALES\n\nHoliday sales are already getting under way throughout the state.\n\n"In Celebration of Hanukkah, Judaic Crafts" will open at the Jewish Community Center in West Orange with a reception at 3 P.M. today. As the show continues through Nov. 21, many regular programs, like lectures and concerts, will begin their seasons.',
#     'web_url': 'https://www.nytimes.com/1994/11/06/nyregion/new-jersey-guide.html',
#     'snippet': 'HOLIDAY SALES\n\nHoliday sales are already getting under way throughout the state.\n\n"In Celebration of Hanukkah, Judaic Crafts" will open at the Jewish Community Center in West Orange with a reception at 3 P.M. today. As the show continues through N...',
#     'lead_paragraph': 'HOLIDAY SALES',
#     'print_section': '13NJ',
#     'print_page': '9',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'NEW JERSEY GUIDE',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'NEW JERSEY GUIDE',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'NO INDEX TERMS',
#       'rank': 1,
#       'major': 'N'}],
#     'pub_date': '1994-11-06T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'New Jersey Weekly Desk',
#     'section_name': 'New York',
#     'subsection_name': 'New Jersey',
#     'byline': {'original': 'By Mary L. Emblen',
#      'person': [{'firstname': 'Mary',
#        'middlename': 'L.',
#        'lastname': 'Emblen',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/a960efa9-5655-5eb0-84a9-61d169c25ac2',
#     'word_count': 907,
#     'uri': 'nyt://article/a960efa9-5655-5eb0-84a9-61d169c25ac2'},
#    {'abstract': '  Heavy advertising and promotional campaigns helped draw shoppers into stores during the weekend, and several retailers reported that their sales in the first two days of the holiday shopping season were slightly better than expected.    But most executives were circumspect about business, and one survey of foot traffic in 33 malls around the country found fewer shoppers this year than last year for the first weekend of holiday shopping.',
#     'web_url': 'https://www.nytimes.com/1994/11/28/business/retailers-cautiously-optimistic.html',
#     'snippet': '',
#     'lead_paragraph': 'Heavy advertising and promotional campaigns helped draw shoppers into stores during the weekend, and several retailers reported that their sales in the first two days of the holiday shopping season were slightly better than expected.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Retailers Cautiously Optimistic',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Retailers Cautiously Optimistic',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '1994-11-28T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/222d86e6-a657-5a9d-9bc6-918e6f395268',
#     'word_count': 1301,
#     'uri': 'nyt://article/222d86e6-a657-5a9d-9bc6-918e6f395268'},
#    {'abstract': "  The prices of Treasury securities rose yesterday, and the yield on the 30-year bond fell to a three-month low in thin holiday trading.   The price of the 30-year bond rose 25/32 , to 971/32 , for a yield of 7.76 percent, down from 7.83 percent on Friday. The rates on the shorter-maturity bills were steady, and at the Treasury's weekly auction of three- and six-month bills, the discount rate declined for the third consecutive week.",
#     'web_url': 'https://www.nytimes.com/1994/12/28/business/credit-markets-prices-rise-for-bonds-in-thin-trading.html',
#     'snippet': '',
#     'lead_paragraph': 'The prices of Treasury securities rose yesterday, and the yield on the 30-year bond fell to a three-month low in thin holiday trading.',
#     'print_section': 'D',
#     'print_page': '15',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Prices Rise For Bonds in Thin Trading',
#      'kicker': 'CREDIT MARKETS',
#      'content_kicker': None,
#      'print_headline': 'CREDIT MARKETS; Prices Rise For Bonds in Thin Trading',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Finances',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Government Bonds',
#       'rank': 2,
#       'major': 'N'}],
#     'pub_date': '1994-12-28T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Robert Hurtado',
#      'person': [{'firstname': 'Robert',
#        'middlename': None,
#        'lastname': 'Hurtado',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/df3cb7ea-1c83-53e2-a83a-8e1bee813c74',
#     'word_count': 865,
#     'uri': 'nyt://article/df3cb7ea-1c83-53e2-a83a-8e1bee813c74'},
#    {'abstract': "  Beth Findlay and her mother, Joan Gorelick, spent yesterday morning browsing at the Stamford Town Center in Stamford, Conn.    In Macy's, they picked up a couple of pairs of earrings that were already gift-wrapped and bought a sports shirt that was on sale for Mrs. Gorelick's husband, Dan. But mostly they just prowled the mall, trying to get into the holiday spirit.",
#     'web_url': 'https://www.nytimes.com/1994/11/26/business/for-holiday-shoppers-no-hurry.html',
#     'snippet': '',
#     'lead_paragraph': 'Beth Findlay and her mother, Joan Gorelick, spent yesterday morning browsing at the Stamford Town Center in Stamford, Conn.',
#     'print_section': '1',
#     'print_page': '39',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'For Holiday Shoppers, No Hurry',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'For Holiday Shoppers, No Hurry',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'SHOPPING CENTERS',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Consumer Behavior',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 5, 'major': 'N'}],
#     'pub_date': '1994-11-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/931156f6-5bc5-51db-afed-370a2addde11',
#     'word_count': 1474,
#     'uri': 'nyt://article/931156f6-5bc5-51db-afed-370a2addde11'},
#    {'abstract': '  The predictions of a strong holiday shopping season were apparently wishful thinking for many retailers, particularly in apparel.    While the numbers will not begin to come out until tomorrow, the early indications are that the season\'s sales, while above last year\'s, have not been what retailers hoped for or stocked for. "It\'s not been a happy season," said Edward Johnson, the retailing analyst who compiles the Johnson Redbook Service, which tracks sales.',
#     'web_url': 'https://www.nytimes.com/1994/12/26/us/retailers-christmas-wishes-didn-t-come-true-this-year.html',
#     'snippet': '',
#     'lead_paragraph': 'The predictions of a strong holiday shopping season were apparently wishful thinking for many retailers, particularly in apparel.',
#     'print_section': '1',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Retailers' Christmas Wishes Didn't Come True This Year",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Retailers' Christmas Wishes Didn't Come True This Year",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'HOLIDAY TRADE',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'APPAREL', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'}],
#     'pub_date': '1994-12-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'National Desk',
#     'section_name': 'U.S.',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/3b396e69-fc20-5f7b-8a86-53b43a546910',
#     'word_count': 1503,
#     'uri': 'nyt://article/3b396e69-fc20-5f7b-8a86-53b43a546910'}],
#   'meta': {'hits': 21, 'offset': 0, 'time': 142}}}

# %%
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': "In this season of gift-giving, Macy's has decided that some members of its sales staff should give the company a Christmas present -- as much as half of their commissions.         Macy's has reduced the percentage of commission for sales representatives during the five-week holiday selling season, cutting deeply into the biggest paychecks many employees receive all year. The reduction hits most sales employees in 15 stores, many of them in the New York suburbs, as well as those who work in commissioned departments at other Macy's stores on the East Coast. A spokesman for Federated Department Stores Inc., which acquired R. H. Macy & Company in 1994 after it emerged from bankruptcy, estimated that about 3,000 sales associates were affected by the change.   ",
#     'web_url': 'https://www.nytimes.com/1995/12/15/business/macy-s-marks-down-some-workers-holiday-sales-commissions.html',
#     'snippet': '',
#     'lead_paragraph': "In this season of gift-giving, Macy's has decided that some members of its sales staff should give the company a Christmas present -- as much as half of their commissions.",
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Macy's Marks Down Some Workers' Holiday Sales Commissions",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Macy's Marks Down Some Workers' Holiday Sales Commissions",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Macy, R H, & Co Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'COMMISSIONS (FEES)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'SALESMEN', 'rank': 4, 'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 5, 'major': 'N'}],
#     'pub_date': '1995-12-15T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Jennifer Steinhauer',
#      'person': [{'firstname': 'Jennifer',
#        'middlename': None,
#        'lastname': 'Steinhauer',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/c2569b51-8667-52b8-b338-3f3d52832045',
#     'word_count': 823,
#     'uri': 'nyt://article/c2569b51-8667-52b8-b338-3f3d52832045'},
#    {'abstract': "Retail sales rebounded last month, the Government reported yesterday, but analysts said consumers remained anxious and they continued to predict a brutally competitive Christmas for retailers.         According to the Commerce Department's early estimates, retail sales rose eight-tenths of 1 percent in November, more than expected, to a seasonally adjusted $197.9 billion.   ",
#     'web_url': 'https://www.nytimes.com/1995/12/14/business/us-reports-a-rebound-in-retail-sales.html',
#     'snippet': '',
#     'lead_paragraph': 'Retail sales rebounded last month, the Government reported yesterday, but analysts said consumers remained anxious and they continued to predict a brutally competitive Christmas for retailers.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'U.S. Reports A Rebound In Retail Sales',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'U.S. Reports A Rebound In Retail Sales',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'United States',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'COMMERCE DEPARTMENT US DEPARTMENT OF COMMERCE',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Discount Selling', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'UNITED STATESECONOMY',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 6, 'major': 'N'}],
#     'pub_date': '1995-12-14T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Kenneth N. Gilpin',
#      'person': [{'firstname': 'Kenneth',
#        'middlename': 'N.',
#        'lastname': 'Gilpin',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/4ee7ae11-73b6-5aec-9ab0-18fb1a30d20d',
#     'word_count': 726,
#     'uri': 'nyt://article/4ee7ae11-73b6-5aec-9ab0-18fb1a30d20d'},
#    {'abstract': "The Standard & Poor's Corporation said today that it would not decide whether to downgrade Kmart's debt until the week of Jan. 8, giving the troubled retailer time to pump up holiday sales and negotiate a deal with debt holders.         The Kmart Corporation, which is based in Troy, Mich., is in talks to change the terms of $681 million in real estate debt, and the outcome could play a central role in the company's financial future.   ",
#     'web_url': 'https://www.nytimes.com/1995/12/19/business/standard-poor-s-delays-a-decision-on-kmart-s-debt.html',
#     'snippet': '',
#     'lead_paragraph': "The Standard & Poor's Corporation said today that it would not decide whether to downgrade Kmart's debt until the week of Jan. 8, giving the troubled retailer time to pump up holiday sales and negotiate a deal with debt holders.",
#     'print_section': 'D',
#     'print_page': '9',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Standard & Poor's Delays A Decision on Kmart's Debt",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Standard & Poor's Delays A Decision on Kmart's Debt",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Kmart Corp',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': "Standard & Poor's Corp",
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Ratings and Rating Systems',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Finances', 'rank': 4, 'major': 'N'}],
#     'pub_date': '1995-12-19T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'Reuters', 'person': [], 'organization': 'Reuters'},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/b8587cd7-cb59-58a2-943f-43f2727dd0f8',
#     'word_count': 317,
#     'uri': 'nyt://article/b8587cd7-cb59-58a2-943f-43f2727dd0f8'},
#    {'abstract': "New orders for computer chips declined in November, the Semiconductor Industry Association said today, indicating that demand could be slowing.         The trade group's book-to-bill ratio, a closely watched gauge of demand for computer chips, fell to 1.14 in November from 1.18 in October.   ",
#     'web_url': 'https://www.nytimes.com/1995/12/12/business/orders-for-computer-chips-fall-along-with-book-to-bill-ratio.html',
#     'snippet': '',
#     'lead_paragraph': 'New orders for computer chips declined in November, the Semiconductor Industry Association said today, indicating that demand could be slowing.',
#     'print_section': 'D',
#     'print_page': '6',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Orders for Computer Chips Fall Along With Book-to-Bill Ratio',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Orders for Computer Chips Fall Along With Book-to-Bill Ratio',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Semiconductor Industry Assn',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Computer Chips', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'DATA PROCESSING (COMPUTERS)',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1995-12-12T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg Business News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': 'Business',
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/410c90a8-8098-58d8-9a87-02bf84782108',
#     'word_count': 267,
#     'uri': 'nyt://article/410c90a8-8098-58d8-9a87-02bf84782108'},
#    {'abstract': 'Tom Luzod was determined to find the bargains, but it took some effort. By 6  A.M. yesterday, he was already at Michaels Arts and Crafts in San Jose, Calif.,  cleaning up at its "50 percent off" sale. By 7, he was at Mervyn\'s department store, where he was one of the first in line so he could scoop up a limited edition Joe Montana collectible trading card.         Not a bad morning\'s work, but Mr. Luzod, 44, was barely started. He arrived at Big 5, a sporting goods store, by 7:30. It was not open yet, but it let him in anyway, lest he lose his momentum.   ',
#     'web_url': 'https://www.nytimes.com/1995/11/25/business/stores-full-but-shoppers-seem-wary.html',
#     'snippet': '',
#     'lead_paragraph': 'Tom Luzod was determined to find the bargains, but it took some effort. By 6 A.M. yesterday, he was already at Michaels Arts and Crafts in San Jose, Calif., cleaning up at its "50 percent off" sale. By 7, he was at Mervyn\'s department store, where he was one of the first in line so he could scoop up a limited edition Joe Montana collectible trading card.',
#     'print_section': '1',
#     'print_page': '37',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Stores Full, But Shoppers Seem Wary',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Stores Full, But Shoppers Seem Wary',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 2, 'major': 'N'}],
#     'pub_date': '1995-11-25T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Jennifer Steinhauer',
#      'person': [{'firstname': 'Jennifer',
#        'middlename': None,
#        'lastname': 'Steinhauer',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/0687bb5f-c95c-540a-80fd-5b78ddfbfae5',
#     'word_count': 1462,
#     'uri': 'nyt://article/0687bb5f-c95c-540a-80fd-5b78ddfbfae5'},
#    {'abstract': 'IT may be the season for glad tidings, but not so far this year for anxious retailers. In Westchester as elsewhere, shopkeepers are reporting brisk foot traffic in their stores in the weeks before Christmas -- but disappointing sales.         "The bottom line is not how crowded the stores are, but how many shoppers are leaving with bags," said Harold E. Vogt, president and chief executive officer of the Westchester Chamber of Commerce. "The consumers may be out there, but whether they\'re buying is another question."   ',
#     'web_url': 'https://www.nytimes.com/1995/12/10/nyregion/merchants-keep-hoping-despite-slow-start.html',
#     'snippet': '',
#     'lead_paragraph': 'IT may be the season for glad tidings, but not so far this year for anxious retailers. In Westchester as elsewhere, shopkeepers are reporting brisk foot traffic in their stores in the weeks before Christmas -- but disappointing sales.',
#     'print_section': 'WC',
#     'print_page': '13',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Merchants Keep Hoping, Despite Slow Start',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Merchants Keep Hoping, Despite Slow Start',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'Westchester County (NY)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Westchester County Chamber of Commerce',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'VOGT, HAROLD E', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'ECONOMIC CONDITIONSAND TRENDS',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'SHOPPING CENTERS', 'rank': 6, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 7, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 8,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Consumer Behavior',
#       'rank': 9,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 10, 'major': 'N'}],
#     'pub_date': '1995-12-10T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Westchester Weekly Desk',
#     'section_name': 'New York',
#     'byline': {'original': 'By Elsa Brenner',
#      'person': [{'firstname': 'Elsa',
#        'middlename': None,
#        'lastname': 'Brenner',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/8d8b337a-a73a-5b53-bd87-129af99002a1',
#     'word_count': 1297,
#     'uri': 'nyt://article/8d8b337a-a73a-5b53-bd87-129af99002a1'},
#    {'abstract': "The fierce competition that has kept consumers awash in bargains has taken a  heavy toll on retailers, industry figures showed today.         Wal-Mart Stores Inc., the nation's largest chain, eked out a modest increase  in profits for its third fiscal quarter, but the Dayton Hudson Corporation, the J. C. Penney Company and the Woolworth Corporation all posted declines.   ",
#     'web_url': 'https://www.nytimes.com/1995/11/15/business/most-retailers-profits-shrink-as-competition-heats-up.html',
#     'snippet': '',
#     'lead_paragraph': 'The fierce competition that has kept consumers awash in bargains has taken a heavy toll on retailers, industry figures showed today.',
#     'print_section': 'D',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Most Retailers' Profits Shrink as Competition Heats Up",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Most Retailers' Profits Shrink as Competition Heats Up",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Commerce Department',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'JOHNSON REDBOOK SERVICE',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Age, Chronological',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'CONSUMER CREDIT (ECONOMIC INDICATOR)',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'INDUSTRY PROFILES',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Discount Selling', 'rank': 8, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 9,
#       'major': 'N'}],
#     'pub_date': '1995-11-15T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Robert D. Hershey Jr',
#      'person': [{'firstname': 'Robert',
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/eda68e31-1a73-5eb3-bc78-a5849afefa70',
#     'word_count': 937,
#     'uri': 'nyt://article/eda68e31-1a73-5eb3-bc78-a5849afefa70'},
#    {'abstract': 'BOGGED down with shopping bags from stores throughout the Roosevelt Field mall, Roy Cotignola and Mary-Jo Thompson were doing their holiday shopping at J. Crew.         "We\'ve already been to Kay-Bee, Disney, Warner Brothers, Learningsmith and the Nature Company," said Ms. Thompson, who traveled to the mall from Queens to  find the items on her holiday list.   ',
#     'web_url': 'https://www.nytimes.com/1995/12/10/nyregion/mall-aglow-with-new-stores-and-real-santa.html',
#     'snippet': '',
#     'lead_paragraph': 'BOGGED down with shopping bags from stores throughout the Roosevelt Field mall, Roy Cotignola and Mary-Jo Thompson were doing their holiday shopping at J. Crew.',
#     'print_section': 'LI',
#     'print_page': '13',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Mall Aglow With New Stores and 'Real' Santa",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Mall Aglow With New Stores and 'Real' Santa",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Roosevelt Field Shopping Center',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'SHOPPING CENTERS', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 5, 'major': 'N'}],
#     'pub_date': '1995-12-10T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Long Island Weekly Desk',
#     'section_name': 'New York',
#     'byline': {'original': 'By Linda Saslow',
#      'person': [{'firstname': 'Linda',
#        'middlename': None,
#        'lastname': 'Saslow',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/9dde2682-aa35-5b17-8507-1c9d4ce2aee6',
#     'word_count': 2370,
#     'uri': 'nyt://article/9dde2682-aa35-5b17-8507-1c9d4ce2aee6'},
#    {'abstract': 'Economic growth is slowing in the United States, two new reports said today,  putting new pressure on the Federal Reserve to reduce interest rates and on Congress and the White House to reach a budget deal.         The Commerce Department announced this morning that its index of leading economic indicators had fallen by half a percentage point in October, the steepest drop since April and the seventh drop in the last nine months. The slide in October was larger than most economists expected and prompted some to warn of a recession if the Federal Reserve did not reduce short-term interest rates soon.   ',
#     'web_url': 'https://www.nytimes.com/1995/12/07/business/fed-weighs-new-evidence-of-slowdown.html',
#     'snippet': '',
#     'lead_paragraph': 'Economic growth is slowing in the United States, two new reports said today, putting new pressure on the Federal Reserve to reduce interest rates and on Congress and the White House to reach a budget deal.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Fed Weighs New Evidence Of Slowdown',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Fed Weighs New Evidence Of Slowdown',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Federal Reserve System',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Commerce Department',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'INTERESTRATES', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'LEADING ECONOMIC INDICATORS',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Credit', 'rank': 6, 'major': 'N'}],
#     'pub_date': '1995-12-07T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Keith Bradsher',
#      'person': [{'firstname': 'Keith',
#        'middlename': None,
#        'lastname': 'Bradsher',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/7b17aa4f-5712-5201-bbeb-f62cf718f7be',
#     'word_count': 876,
#     'uri': 'nyt://article/7b17aa4f-5712-5201-bbeb-f62cf718f7be'},
#    {'abstract': 'I put together this collection of songs to accompany my novel, \'Where Love Goes,\' so readers could have the experience of hearing some of the music I listen to when I write. And out of my lifelong belief that almost any experience goes better with music." -- Joyce Maynard    TO: Murray Lawrence, Marketing Director FROM: Ed Branden, Publicity Coordinator      Murray:   ',
#     'web_url': 'https://www.nytimes.com/1995/11/05/magazine/endpaper-no-but-i-heard-the-soundtrack.html',
#     'snippet': '',
#     'lead_paragraph': 'I put together this collection of songs to accompany my novel, \'Where Love Goes,\' so readers could have the experience of hearing some of the music I listen to when I write. And out of my lifelong belief that almost any experience goes better with music." -- Joyce Maynard TO: Murray Lawrence, Marketing Director FROM: Ed Branden, Publicity Coordinator',
#     'print_section': '6',
#     'print_page': '92',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'ENDPAPER;No, but I Heard the Soundtrack',
#      'kicker': 'ENDPAPER',
#      'content_kicker': None,
#      'print_headline': 'ENDPAPER;No, but I Heard the Soundtrack',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'RECORDINGS (AUDIO)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Music', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Books and Literature',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '1995-11-05T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Magazine Desk',
#     'section_name': 'Magazine',
#     'byline': {'original': 'By George Kalogerakis',
#      'person': [{'firstname': 'George',
#        'middlename': None,
#        'lastname': 'Kalogerakis',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/4ba67cde-923b-576a-87d5-e6748790a41d',
#     'word_count': 1012,
#     'uri': 'nyt://article/4ba67cde-923b-576a-87d5-e6748790a41d'}],
#   'meta': {'hits': 10, 'offset': 0, 'time': 125}}}

# %%
articles_96 = api.search(q="holiday sales",begin_date=19961101, end_date=19961231)
articles_96

# %%
articles_97 = api.search(q="holiday sales",begin_date=19971101, end_date=19971231)
articles_97
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': "Treasury prices ended slightly higher yesterday in very light trading.     Talk of disappointing holiday retail sales and the dollar's advance against the Japanese yen helped bonds yesterday, but traders said the moves were meaningless because they occurred on such thin trading volume.  ",
#     'web_url': 'https://www.nytimes.com/1997/12/27/business/treasury-prices-move-higher-helped-by-slow-holiday-sales.html',
#     'snippet': '',
#     'lead_paragraph': 'Treasury prices ended slightly higher yesterday in very light trading.',
#     'print_section': 'D',
#     'print_page': '10',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Treasury Prices Move Higher, Helped by Slow Holiday Sales',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Treasury Prices Move Higher, Helped by Slow Holiday Sales',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1997-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bridge News',
#      'person': [{'firstname': 'Bridge',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/2ccd36b1-47a3-5117-909e-7b1fc37abf8b',
#     'word_count': 302,
#     'uri': 'nyt://article/2ccd36b1-47a3-5117-909e-7b1fc37abf8b'},
#    {'abstract': 'Retailers Finding Sales Disappoint For The Holidays** Sparkling economy, record-low unemployment and fatter paychecks failed to translate into big holiday selling season retailers were counting on; retailers estimate sales rose scant 2% to 3% in December from year earlier, half gain some analysts had touted at start of holiday season; analysts say lackluster performance underscores harsh necessity for retailers to come to grips with diminishing role of Christmas-season sales and to find more creative ways of getting people to part with cash (M)',
#     'web_url': 'https://www.nytimes.com/1997/12/26/business/retailers-finding-sales-disappoint-for-the-holidays.html',
#     'snippet': 'Retailers Finding Sales Disappoint For The Holidays** Sparkling economy, record-low unemployment and fatter paychecks failed to translate into big holiday selling season retailers were counting on; retailers estimate sales rose scant 2% to 3% in D...',
#     'lead_paragraph': 'A sparkling economy, record-low unemployment and fatter paychecks failed to translate into the strapping holiday selling season American retailers were counting on.',
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'RETAILERS FINDING SALES DISAPPOINT FOR THE HOLIDAYS',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'RETAILERS FINDING SALES DISAPPOINT FOR THE HOLIDAYS',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'UNEMPLOYMENT AND JOB MARKET',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'LABOR', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Wages and Salaries',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Forecasts', 'rank': 6, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 8, 'major': 'N'}],
#     'pub_date': '1997-12-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Jennifer Steinhauer',
#      'person': [{'firstname': 'Jennifer',
#        'middlename': None,
#        'lastname': 'Steinhauer',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/cc9db355-6803-5d73-98cf-bb55bab8578e',
#     'word_count': 1438,
#     'uri': 'nyt://article/cc9db355-6803-5d73-98cf-bb55bab8578e'},
#    {'abstract': "It's become as much a part of the seasonal ritual as caroling and trimming the tree: moaning about disappointing holiday sales.    For the third consecutive year in a roaring economy, people didn't buy as much as experts thought they would. Retailers and those who watch them estimated that sales rose only 2 to 3 percent in December from the year before, about half the gain analysts had predicted at the start of the shopping season.  ",
#     'web_url': 'https://www.nytimes.com/1997/12/28/weekinreview/december-21-27-now-only-362-shopping-days-left.html',
#     'snippet': '',
#     'lead_paragraph': "It's become as much a part of the seasonal ritual as caroling and trimming the tree: moaning about disappointing holiday sales.",
#     'print_section': '4',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'December 21-27; Now, Only 362 Shopping Days Left',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'December 21-27; Now, Only 362 Shopping Days Left',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1997-12-28T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Week in Review Desk',
#     'section_name': 'Week in Review',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/c351a2f5-ac62-5f9a-8a92-f484fd6a7882',
#     'word_count': 197,
#     'uri': 'nyt://article/c351a2f5-ac62-5f9a-8a92-f484fd6a7882'},
#    {'abstract': 'Retail sales were light over Thanksgiving Day holiday weekend, despite packed malls and lines at discount stores; graph (M)',
#     'web_url': 'https://www.nytimes.com/1997/12/01/us/holiday-shoppers-start-selectively-lining-up-for-1997-s-hot-items-for-discounts.html',
#     'snippet': 'Retail sales were light over Thanksgiving Day holiday weekend, despite packed malls and lines at discount stores; graph (M)',
#     'lead_paragraph': 'If ever a Thanksgiving weekend underscored the way Americans now shop for the holidays, this one was it.',
#     'print_section': 'A',
#     'print_page': '19',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Holiday Shoppers Start Selectively, Lining Up for 1997's Hot Items and for Discounts",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Holiday Shoppers Start Selectively, Lining Up for 1997's Hot Items and for Discounts",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Thanksgiving Day',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'SHOPPING CENTERS', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Holidays and Special Occasions',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 5, 'major': 'N'}],
#     'pub_date': '1997-12-01T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'National Desk',
#     'section_name': 'U.S.',
#     'byline': {'original': 'By Jennifer Steinhauer',
#      'person': [{'firstname': 'Jennifer',
#        'middlename': None,
#        'lastname': 'Steinhauer',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/c66c35c4-68e7-59d3-8d66-3b9e7bcec34b',
#     'word_count': 1139,
#     'uri': 'nyt://article/c66c35c4-68e7-59d3-8d66-3b9e7bcec34b'},
#    {'abstract': "National Association of Purchasing Management's annual forecast shows US manufacturers are optimistic about coming year despite uncertainty over Asia's financial crisis, expecting stronger revenues, increased employment and stable prices (S)",
#     'web_url': 'https://www.nytimes.com/1997/12/10/business/survey-shows-manufacturers-optimistic.html',
#     'snippet': "National Association of Purchasing Management's annual forecast shows US manufacturers are optimistic about coming year despite uncertainty over Asia's financial crisis, expecting stronger revenues, increased employment and stable prices (S)",
#     'lead_paragraph': "United States manufacturers are optimistic about the coming year despite uncertainty over Asia's financial crisis, expecting stronger revenues, increased employment and stable prices, a group of factory purchasing executives said yesterday.",
#     'print_section': 'D',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Survey Shows Manufacturers Optimistic',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Survey Shows Manufacturers Optimistic',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'Far East, South and Southeast Asia and Pacific Areas',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'NATIONAL ASSN OF PURCHASING MANAGEMENT',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'UNEMPLOYMENT AND JOB MARKET',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'LABOR', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Prices (Fares, Fees and Rates)',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Forecasts', 'rank': 7, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Economic Conditions and Trends',
#       'rank': 8,
#       'major': 'N'}],
#     'pub_date': '1997-12-10T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/8b3dc093-5b11-5db6-99a0-642c05c2a9e3',
#     'word_count': 178,
#     'uri': 'nyt://article/8b3dc093-5b11-5db6-99a0-642c05c2a9e3'},
#    {'abstract': 'Outlook for investing in retailing stocks discussed in light of soaring retailing stock prices and hopes of robust holiday sales; holdings of some diversified mutual funds that have made large bets on retailing discussed; graphs; photos (M)',
#     'web_url': 'https://www.nytimes.com/1997/11/30/business/mutual-funds-specialty-not-season-makes-retailing-attractive.html',
#     'snippet': 'Outlook for investing in retailing stocks discussed in light of soaring retailing stock prices and hopes of robust holiday sales; holdings of some diversified mutual funds that have made large bets on retailing discussed; graphs; photos (M)',
#     'lead_paragraph': 'STOCK traders are not the only ones prone to irrational exuberance. Year after year, merchants fatten their inventories in preparation for a blockbuster holiday shopping season, often slashing prices later when goods languish on the shelves.',
#     'print_section': '3',
#     'print_page': '6',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Specialty, Not Season, Makes Retailing Attractive',
#      'kicker': 'MUTUAL FUNDS',
#      'content_kicker': None,
#      'print_headline': 'MUTUAL FUNDS; Specialty, Not Season, Makes Retailing Attractive',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Mutual Funds',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Stocks and Bonds', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '1997-11-30T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Money and Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Timothy Middleton',
#      'person': [{'firstname': 'Timothy',
#        'middlename': None,
#        'lastname': 'Middleton',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/b08c3a7f-ae21-51b8-9479-c7c8065d507c',
#     'word_count': 1338,
#     'uri': 'nyt://article/b08c3a7f-ae21-51b8-9479-c7c8065d507c'},
#    {'abstract': " NBC Losing 'Seinfeld' At the End of the Season   The most popular television comedy of the 1990's, ''Seinfeld,'' will shut down production at the end of this season. The decision by the show's creator and star, Jerry Seinfeld, is a blow to NBC, which has seen its prime-time strength weaken this season.  ",
#     'web_url': 'https://www.nytimes.com/1997/12/26/business/business-digest-784478.html',
#     'snippet': '',
#     'lead_paragraph': "NBC Losing 'Seinfeld' At the End of the Season",
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'BUSINESS DIGEST',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'BUSINESS DIGEST',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1997-12-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/cf6ec32c-e017-5666-83a0-b8bd51b0db15',
#     'word_count': 448,
#     'uri': 'nyt://article/cf6ec32c-e017-5666-83a0-b8bd51b0db15'},
#    {'abstract': "Article contends that this holiday season may be first in which consumers give businesses that offer goods and services on Internet a significant amount of sales; many Internet merchants have found that volume is up sharply this year as more consumers learn how to find what they want and become comfortable that they will not be defrauded; American Express Co calculates that $4 billion to $6 billion will be spent making credit card purchases over Internet this year, with sales increasing at more than 400 percent pace annually; more conservatively, Forrester Research puts figure at $2.4 billion, double last year's total (M)",
#     'web_url': 'https://www.nytimes.com/1997/12/01/business/money-starts-to-show-in-internet-shopping.html',
#     'snippet': 'Article contends that this holiday season may be first in which consumers give businesses that offer goods and services on Internet a significant amount of sales; many Internet merchants have found that volume is up sharply this year as more consu...',
#     'lead_paragraph': "For all the chat, the browsing, the waiting and the endless cyberhype, much of American business has stared at the Internet and thought, skeptically: ''Show me the money.''",
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Money Starts to Show in Internet Shopping',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Money Starts to Show in Internet Shopping',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'AMERICAN EXPRESS CO',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Forrester Research Inc',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'COMPUTERS AND INFORMATION SYSTEMS',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'CREDIT CARDS AND ACCOUNTS',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'INTERNET AND WORLD WIDE WEB',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 6,
#       'major': 'N'}],
#     'pub_date': '1997-12-01T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Saul Hansell',
#      'person': [{'firstname': 'Saul',
#        'middlename': None,
#        'lastname': 'Hansell',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/e3cad612-2d25-58a6-af6f-c7b562594204',
#     'word_count': 1219,
#     'uri': 'nyt://article/e3cad612-2d25-58a6-af6f-c7b562594204'},
#    {'abstract': "James Jackson headed toward the J. C. Penney's in the Connecticut Post Mall in Milford, wearing a determined look and a dark leather jacket. His destination: the return and refund line.    ''I wouldn't wear these if it were 20 below,'' he said, displaying a pair of purple woolen gloves. ''I would rather get frostbite.''  ",
#     'web_url': 'https://www.nytimes.com/1997/12/27/nyregion/for-many-it-is-the-time-for-the-joy-of-returning.html',
#     'snippet': '',
#     'lead_paragraph': "James Jackson headed toward the J. C. Penney's in the Connecticut Post Mall in Milford, wearing a determined look and a dark leather jacket. His destination: the return and refund line.",
#     'print_section': 'B',
#     'print_page': '3',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'For Many, It Is the Time For the Joy of Returning',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'For Many, It Is the Time For the Joy of Returning',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1997-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Metropolitan Desk',
#     'section_name': 'New York',
#     'byline': {'original': 'By Monte Williams',
#      'person': [{'firstname': 'Monte',
#        'middlename': None,
#        'lastname': 'Williams',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/15b23197-52c5-5b02-a160-c42b727ca243',
#     'word_count': 746,
#     'uri': 'nyt://article/15b23197-52c5-5b02-a160-c42b727ca243'},
#    {'abstract': "Toy industry has high hopes for holiday season; unusually wide range of hot toys is on market this year, including some updated classics and several newcomers; action figures tied to blockbuster movies are already vanishing from store shelves, and plush toys have made comeback; industry is counting on broad mix of playthings to keep merchants from pinning their hopes on few standout toys that may be out of stock long before Christmas; Toy Manufacturers of America says it expects value of toys shipped to exceed last year's $14.5 billion by at least 5 percent; photos (M)",
#     'web_url': 'https://www.nytimes.com/1997/11/06/business/toy-market-sees-green-and-purple-holidays.html',
#     'snippet': 'Toy industry has high hopes for holiday season; unusually wide range of hot toys is on market this year, including some updated classics and several newcomers; action figures tied to blockbuster movies are already vanishing from store shelves, and...',
#     'lead_paragraph': 'That annoying purple dinosaur has teamed up with Bill Gates, that first-time dad, to go interactive. Holiday Barbie has a dye job -- she is a brunette for the first time. And youngsters are bonding in a big way with electronic key chains that need to eat, sleep and study.',
#     'print_section': 'D',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Toy Market Sees Green and Purple Holidays',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Toy Market Sees Green and Purple Holidays',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Toy Manufacturers of America',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Toys', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 3, 'major': 'N'}],
#     'pub_date': '1997-11-06T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Dana Canedy',
#      'person': [{'firstname': 'Dana',
#        'middlename': None,
#        'lastname': 'Canedy',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/ad34d14e-8823-54b3-8c2c-fe09e6994b2a',
#     'word_count': 1063,
#     'uri': 'nyt://article/ad34d14e-8823-54b3-8c2c-fe09e6994b2a'}],
#   'meta': {'hits': 16, 'offset': 0, 'time': 122}}}

# %%
articles_98 = api.search(q="holiday sales",begin_date=19981101, end_date=19981231)
articles_98
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Specialty stores and discounters outdistance major department store chains in holiday sales during November; chart shows retail sales in November; table shows results for various stores (M)',
#     'web_url': 'https://www.nytimes.com/1998/12/04/business/discounters-report-strong-holiday-sales.html',
#     'snippet': 'Specialty stores and discounters outdistance major department store chains in holiday sales during November; chart shows retail sales in November; table shows results for various stores (M)',
#     'lead_paragraph': 'Specialty stores and discounters outdistanced major department store chains in holiday sales during November, monthly results from big retailers showed yesterday.',
#     'print_section': 'C',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Discounters Report Strong Holiday Sales',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Discounters Report Strong Holiday Sales',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Discount Selling',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'}],
#     'pub_date': '1998-12-04T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Sharon R. King',
#      'person': [{'firstname': 'Sharon',
#        'middlename': 'R.',
#        'lastname': 'King',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/7845ee69-a873-5829-98a6-676a79349120',
#     'word_count': 623,
#     'uri': 'nyt://article/7845ee69-a873-5829-98a6-676a79349120'},
#    {'abstract': 'Bank of Tokyo-Mitsubishi Ltd says retailers across the nation reported better-than-expected 4.8 percent sales rise in October, led by demand for clothes at specialty shops and name-brand goods at discount retailers; sales figures for specific retailers noted (M)',
#     'web_url': 'https://www.nytimes.com/1998/11/06/business/retailers-say-october-sales-were-better-than-expected.html',
#     'snippet': 'Bank of Tokyo-Mitsubishi Ltd says retailers across the nation reported better-than-expected 4.8 percent sales rise in October, led by demand for clothes at specialty shops and name-brand goods at discount retailers; sales figures for specific reta...',
#     'lead_paragraph': 'Retailers across the nation reported a better-than-expected 4.8 percent sales rise in October yesterday, led by demand for clothes at specialty shops and name-brand goods at discount retailers.',
#     'print_section': 'C',
#     'print_page': '9',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Retailers Say October Sales Were Better Than Expected',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Retailers Say October Sales Were Better Than Expected',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Bank of Tokyo-Mitsubishi Ltd',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '1998-11-06T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/c18a8f44-59b7-58ce-b68f-4142c9d0ec94',
#     'word_count': 461,
#     'uri': 'nyt://article/c18a8f44-59b7-58ce-b68f-4142c9d0ec94'},
#    {'abstract': 'Holiday sales figures for Internet retailers show huge season, stronger even than most bullish predictions, with on-line sales expected to reach $5 billion; Boston Consulting Group reports year-to-year sales grew more than threefold during recent holiday season, with apparel sales especially strong, reaching $300 million from less than $100 million in 1997; photo (M)',
#     'web_url': 'https://www.nytimes.com/1998/12/29/business/estimates-for-on-line-shopping-exceed-the-most-bullish-forecasts.html',
#     'snippet': 'Holiday sales figures for Internet retailers show huge season, stronger even than most bullish predictions, with on-line sales expected to reach $5 billion; Boston Consulting Group reports year-to-year sales grew more than threefold during recent ...',
#     'lead_paragraph': 'Holiday sales figures for Internet retailers released yesterday showed a huge season -- stronger than even the most bullish predictions of a month ago.',
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Estimates for On-Line Shopping Exceed the Most Bullish Forecasts',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Estimates for On-Line Shopping Exceed the Most Bullish Forecasts',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Boston Consulting Group',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'COMPUTERS AND INFORMATION SYSTEMS',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'INTERNET AND WORLD WIDE WEB',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'APPAREL', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 6, 'major': 'N'}],
#     'pub_date': '1998-12-29T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Leslie Kaufman and Saul Hansell',
#      'person': [{'firstname': 'Leslie',
#        'middlename': None,
#        'lastname': 'Kaufman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1},
#       {'firstname': 'Saul',
#        'middlename': None,
#        'lastname': 'Hansell',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 2}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/4d42663f-9aea-54ea-9647-15c45e16fbef',
#     'word_count': 1122,
#     'uri': 'nyt://article/4d42663f-9aea-54ea-9647-15c45e16fbef'},
#    {'abstract': 'Department store executives express cautious optimism about sales for 1998 holiday season as unexpectedly warm weather brought hordes of shoppers to malls during Thanksgiving weekend; photo (M)',
#     'web_url': 'https://www.nytimes.com/1998/11/30/business/holiday-shopping-off-to-good-start.html',
#     'snippet': 'Department store executives express cautious optimism about sales for 1998 holiday season as unexpectedly warm weather brought hordes of shoppers to malls during Thanksgiving weekend; photo (M)',
#     'lead_paragraph': 'While unexpectedly warm weather brought hordes of shoppers to malls during the Thanksgiving weekend, most department store executives expressed just cautious optimism yesterday about sales for the holiday season.',
#     'print_section': 'A',
#     'print_page': '20',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Holiday Shopping Off to Good Start',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Holiday Shopping Off to Good Start',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Thanksgiving Day',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Forecasts', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'}],
#     'pub_date': '1998-11-30T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Sharon R. King',
#      'person': [{'firstname': 'Sharon',
#        'middlename': 'R.',
#        'lastname': 'King',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/ef0eb9cc-701c-5932-bf0a-19e198a30537',
#     'word_count': 1037,
#     'uri': 'nyt://article/ef0eb9cc-701c-5932-bf0a-19e198a30537'},
#    {'abstract': 'National Association of Purchasing Management says US manufacturers are less optimistic about coming year, expecting revenues will rise at slower pace than in 1998, while nonmanufacturing companies are more upbeat (S)',
#     'web_url': 'https://www.nytimes.com/1998/12/09/business/manufacturers-are-less-upbeat.html',
#     'snippet': 'National Association of Purchasing Management says US manufacturers are less optimistic about coming year, expecting revenues will rise at slower pace than in 1998, while nonmanufacturing companies are more upbeat (S)',
#     'lead_paragraph': 'United States manufacturers are less optimistic about the coming year, expecting revenues will rise at a slower pace than in 1998, while nonmanufacturing companies are more upbeat, according to the National Association of Purchasing Management.',
#     'print_section': 'C',
#     'print_page': '7',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Manufacturers Are Less Upbeat',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Manufacturers Are Less Upbeat',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'NATIONAL ASSN OF PURCHASING MANAGEMENT',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 2,
#       'major': 'N'}],
#     'pub_date': '1998-12-09T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/5742e42b-44c2-5f22-912c-ca172d9554a6',
#     'word_count': 170,
#     'uri': 'nyt://article/5742e42b-44c2-5f22-912c-ca172d9554a6'},
#    {'abstract': " Merchants and Analysts Predict Solid Holiday Sales  Largely undistracted by the impeachment of President Clinton and the bombing of Iraq, American shoppers appear to have spent freely from wallets that still feel pretty fat, giving retailers a bright, if not stellar, holiday season.    Though industry figures will not be officially reported until early January, retail analysts and merchants are predicting that December sales in big chain stores open at least one year will rise for the second year in a row by as much as 4 percent to 5 percent. Other retailers are expecting solid gains as well. [Page A1.]    Daimler Forecasts '98 Results  DaimlerChrysler, the world's fifth-largest auto maker, said that its 1998 combined sales would rise more than 13 percent and that profit would exceed last year's figures of the combined Daimler-Benz and Chrysler. [C2.]  ",
#     'web_url': 'https://www.nytimes.com/1998/12/28/business/business-digest-618349.html',
#     'snippet': '',
#     'lead_paragraph': 'Merchants and Analysts Predict Solid Holiday Sales',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'BUSINESS DIGEST',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'BUSINESS DIGEST',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1998-12-28T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/12d250dd-581c-5b3c-98a2-e033d00e0bcd',
#     'word_count': 549,
#     'uri': 'nyt://article/12d250dd-581c-5b3c-98a2-e033d00e0bcd'},
#    {'abstract': 'American shoppers spent freely during year-end holiday season, giving retailers muscular, if not stellar, returns; retail analysts and merchants predict December 1998 sales at big-chain stores open for at least one year will rise for second year in row by as much as 4 percent to 5 percent; say current trend reflects generally buoyant consumer spending and overall economic picture that remains quite rosy; photo (M)',
#     'web_url': 'https://www.nytimes.com/1998/12/28/us/surge-of-shopping-in-december-gives-merchants-a-lift.html',
#     'snippet': 'American shoppers spent freely during year-end holiday season, giving retailers muscular, if not stellar, returns; retail analysts and merchants predict December 1998 sales at big-chain stores open for at least one year will rise for second year i...',
#     'lead_paragraph': 'Largely undistracted by the impeachment of President Clinton and the bombing of Iraq, American shoppers appear to have spent freely from wallets that still feel pretty fat, giving retailers a muscular, if not stellar, holiday season.',
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'SURGE OF SHOPPING IN DECEMBER GIVES MERCHANTS A LIFT',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'SURGE OF SHOPPING IN DECEMBER GIVES MERCHANTS A LIFT',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Forecasts', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'}],
#     'pub_date': '1998-12-28T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'National Desk',
#     'section_name': 'U.S.',
#     'byline': {'original': 'By Leslie Kaufman',
#      'person': [{'firstname': 'Leslie',
#        'middlename': None,
#        'lastname': 'Kaufman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/9d8cb2df-4f16-5b41-8829-d98d50b4e48a',
#     'word_count': 1482,
#     'uri': 'nyt://article/9d8cb2df-4f16-5b41-8829-d98d50b4e48a'},
#    {'abstract': ' Preliminary Reports Show Brisk Sales on Internet  The first reports on holiday sales for Internet retailers showed results that surpassed even what earlier this month had seemed to be hyped-up preseason predictions. The increases came despite glitches that forced consumers to suffer indignities like access denial to Web sites and despite holiday gifts that did not arrive on time as promised.    The figures are preliminary, and even the most optimistic prediction would be far less than 1 percent of the $2.6 trillion in retail sales in the United States for the year, leading many analysts to remain skeptical about the wave of euphoria generated by the data. [Page A1.]',
#     'web_url': 'https://www.nytimes.com/1998/12/29/business/business-digest-630098.html',
#     'snippet': '',
#     'lead_paragraph': 'Preliminary Reports Show Brisk Sales on Internet',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'BUSINESS DIGEST',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'BUSINESS DIGEST',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1998-12-29T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/9b10696c-7866-528e-8ce8-eff86e60a855',
#     'word_count': 526,
#     'uri': 'nyt://article/9b10696c-7866-528e-8ce8-eff86e60a855'},
#    {'abstract': 'Retailers around the country say balmy temperatures in recent weeks have dampened buying interest in winter items; photo (M)9',
#     'web_url': 'https://www.nytimes.com/1998/12/12/business/some-may-like-it-hot-but-not-retailers.html',
#     'snippet': 'Retailers around the country say balmy temperatures in recent weeks have dampened buying interest in winter items; photo (M)9',
#     'lead_paragraph': 'At Scheels Ace Hardware in Fargo, N.D., they cannot even give the snow blowers away.',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Some May Like It Hot, but Not Retailers',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Some May Like It Hot, but Not Retailers',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Weather',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 2,
#       'major': 'N'}],
#     'pub_date': '1998-12-12T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Sharon R. King',
#      'person': [{'firstname': 'Sharon',
#        'middlename': 'R.',
#        'lastname': 'King',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/8580b5bc-f95f-5148-a246-b6c8d6ba6df3',
#     'word_count': 1029,
#     'uri': 'nyt://article/8580b5bc-f95f-5148-a246-b6c8d6ba6df3'},
#    {'abstract': "Discount merchandisers are winning nation's shopping wars, cashing in on consumers' growing appetite for bargains; and they are likely to keep their edge through Christmas and Hanukkah frenzy, at the expense of old-line department stores and some specialty chains; graph; photos (M)",
#     'web_url': 'https://www.nytimes.com/1998/11/26/business/frankincense-and-frugality-shoppers-are-making-lists-and-flocking-to-discounters.html',
#     'snippet': "Discount merchandisers are winning nation's shopping wars, cashing in on consumers' growing appetite for bargains; and they are likely to keep their edge through Christmas and Hanukkah frenzy, at the expense of old-line department stores and some ...",
#     'lead_paragraph': "Don't look for elves in the full-price stores this year.",
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Frankincense and Frugality; Shoppers Are Making Lists and Flocking to Discounters',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Frankincense and Frugality; Shoppers Are Making Lists and Flocking to Discounters',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Consumer Behavior',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'},
#      {'name': 'subject', 'value': 'Hanukkah', 'rank': 5, 'major': 'N'}],
#     'pub_date': '1998-11-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Sharon R. King',
#      'person': [{'firstname': 'Sharon',
#        'middlename': 'R.',
#        'lastname': 'King',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/cb9ffe14-302a-5b2f-b594-b92d6175546c',
#     'word_count': 1576,
#     'uri': 'nyt://article/cb9ffe14-302a-5b2f-b594-b92d6175546c'}],
#   'meta': {'hits': 27, 'offset': 0, 'time': 86}}}

# %%
articles_99 = api.search(q="holiday sales",begin_date=19991101, end_date=19991231)
articles_99
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Holiday retail purchases made in New York City and paid for with checks increase 7.2 percent from last year; Mayor Rudolph Giuliani says data show strength of holiday shopping season in city (S)',
#     'web_url': 'https://www.nytimes.com/1999/12/29/nyregion/holiday-sales-paid-by-check-increase-by-7.2-over-1998.html',
#     'snippet': 'Holiday retail purchases made in New York City and paid for with checks increase 7.2 percent from last year; Mayor Rudolph Giuliani says data show strength of holiday shopping season in city (S)',
#     'lead_paragraph': 'In a measure of particularly strong holiday shopping in New York City, retail sales for the season increased by 7.2 percent for purchases paid for by check compared with last year, an industry study showed.',
#     'print_section': 'B',
#     'print_page': '7',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Holiday Sales Paid by Check Increase by 7.2% Over 1998',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Holiday Sales Paid by Check Increase by 7.2% Over 1998',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'New York City',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Giuliani, Rudolph W',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Checks and Checking Accounts',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 6, 'major': 'N'}],
#     'pub_date': '1999-12-29T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Metropolitan Desk',
#     'section_name': 'New York',
#     'byline': {'original': 'By Thomas J. Lueck',
#      'person': [{'firstname': 'Thomas',
#        'middlename': 'J.',
#        'lastname': 'Lueck',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/c4b7554f-faec-559d-b0a9-c904d5dfadce',
#     'word_count': 536,
#     'uri': 'nyt://article/c4b7554f-faec-559d-b0a9-c904d5dfadce'},
#    {'abstract': 'Commerce Department reports inventories rose four-tenths of 1 percent in September after three-tenths of 1 percent increase in August; business sales fell for first time since January, dropping two-tenths of 1 percent in September after 1.2 percent gain in August (S)',
#     'web_url': 'https://www.nytimes.com/1999/11/16/business/a-0.4-jump-in-inventories-for-september.html',
#     'snippet': 'Commerce Department reports inventories rose four-tenths of 1 percent in September after three-tenths of 1 percent increase in August; business sales fell for first time since January, dropping two-tenths of 1 percent in September after 1.2 percen...',
#     'lead_paragraph': "The nation's businesses stockpiled goods in September at the fastest pace in six months, led by wholesalers counting on increased holiday sales, Commerce Department figures showed today.",
#     'print_section': 'C',
#     'print_page': '13',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A 0.4% Jump In Inventories For September',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A 0.4% Jump In Inventories For September',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Commerce Department',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'INVENTORIES (ECONOMIC INDICATOR)',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '1999-11-16T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/6c856ab6-9f50-5ec5-b546-57b865a825c7',
#     'word_count': 282,
#     'uri': 'nyt://article/6c856ab6-9f50-5ec5-b546-57b865a825c7'},
#    {'abstract': "Unseasonably warm weather put damper on retail sales for much of November, but exceptionally bullish week of shopping after Thanksgiving helped get nation's merchants back on track for strong Christmas season; sales rose 2.9 percent in November--smallest since September 1997 (M)",
#     'web_url': 'https://www.nytimes.com/1999/12/03/business/november-a-funny-month-for-the-nation-s-retailers.html',
#     'snippet': "Unseasonably warm weather put damper on retail sales for much of November, but exceptionally bullish week of shopping after Thanksgiving helped get nation's merchants back on track for strong Christmas season; sales rose 2.9 percent in November--s...",
#     'lead_paragraph': "Unseasonably warm weather put a damper on retail sales for much of November, but an exceptionally bullish week of shopping after Thanksgiving helped get the nation's merchants back on track for a strong Christmas season.",
#     'print_section': 'C',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "November a 'Funny Month' For the Nation's Retailers",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "November a 'Funny Month' For the Nation's Retailers",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 1,
#       'major': 'N'}],
#     'pub_date': '1999-12-03T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Leslie Kaufman',
#      'person': [{'firstname': 'Leslie',
#        'middlename': None,
#        'lastname': 'Kaufman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/2bb64776-319a-502a-884b-9c23dd798cb2',
#     'word_count': 818,
#     'uri': 'nyt://article/2bb64776-319a-502a-884b-9c23dd798cb2'},
#    {'abstract': 'Consumer optimism rebounded in November, bolstered by rising incomes and stock prices, just as retailers geared up for the holiday shopping season, Conference Board figures showed yesterday.    The consumer confidence index climbed to 135.8 in November from 130.5 in October, the New York-based research group reported. The index is the highest since August, and the increase follows four months of declines.  ',
#     'web_url': 'https://www.nytimes.com/1999/12/01/business/monthly-index-registers-burst-of-hope-by-consumers.html',
#     'snippet': '',
#     'lead_paragraph': 'Consumer optimism rebounded in November, bolstered by rising incomes and stock prices, just as retailers geared up for the holiday shopping season, Conference Board figures showed yesterday.',
#     'print_section': 'C',
#     'print_page': '8',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Monthly Index Registers Burst of Hope By Consumers',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Monthly Index Registers Burst of Hope By Consumers',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '1999-12-01T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/7ace3054-430b-5b2f-9627-ee21e691acbe',
#     'word_count': 423,
#     'uri': 'nyt://article/7ace3054-430b-5b2f-9627-ee21e691acbe'},
#    {'abstract': "Online holiday shopping is gnawing at business of traditional retailers this year, with preliminary indications that seasonal Internet sales may nearly triple from last year Visa, which represents about half nation's credit card spending, estimates that Internet shoppers using its cards will have spent $1.47 billion this November and December, 179 percent more than last year; in overall retail market that figure is still small, 1.79 persent of Visa's total retail sales; with economy buoyant and retail sales expected to rise an overall six percent this holiday season, big store chains have yet to see Internet take a substantial bite out of their sales; but this may mask a more troublesome phenomenon as stores find that their most affluent customers are the quickest to move online (M)",
#     'web_url': 'https://www.nytimes.com/1999/12/24/business/retailers-look-back-and-see-online-shopping-is-gaining.html',
#     'snippet': "Online holiday shopping is gnawing at business of traditional retailers this year, with preliminary indications that seasonal Internet sales may nearly triple from last year Visa, which represents about half nation's credit card spending, estimate...",
#     'lead_paragraph': 'Online holiday shopping is increasingly gnawing at the business of traditional retailers this year, with preliminary indications that seasonal Internet sales may nearly triple from last year.',
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Retailers Look Back and See Online Shopping Is Gaining',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Retailers Look Back and See Online Shopping Is Gaining',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'VISA INTERNATIONAL INC',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Credit and Money Cards',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 5, 'major': 'N'}],
#     'pub_date': '1999-12-24T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Saul Hansell',
#      'person': [{'firstname': 'Saul',
#        'middlename': None,
#        'lastname': 'Hansell',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/e529af1c-db25-550b-8dff-8b2afef2940a',
#     'word_count': 1168,
#     'uri': 'nyt://article/e529af1c-db25-550b-8dff-8b2afef2940a'},
#    {'abstract': 'Commerce Department reports personal incomes in October rose at fastest pace in five and half years; incomes rose 1.3 percent after no change in September; personal spending grew 0.6 percent, topping 0.5 percent in September; spending has risen at 7.4 percent annual rate in first 10 months of year, compared with 6.8 percent year earlier; graph (M)',
#     'web_url': 'https://www.nytimes.com/1999/11/27/business/personal-incomes-in-october-had-largest-rise-since-1994.html',
#     'snippet': 'Commerce Department reports personal incomes in October rose at fastest pace in five and half years; incomes rose 1.3 percent after no change in September; personal spending grew 0.6 percent, topping 0.5 percent in September; spending has risen at...',
#     'lead_paragraph': 'Personal incomes in October rose at the fastest pace in five and a half years, bolstering consumer spending and paving the way for what may be the strongest holiday shopping season this decade.',
#     'print_section': 'C',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Personal Incomes in October Had Largest Rise Since 1994',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Personal Incomes in October Had Largest Rise Since 1994',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Commerce Department',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Income', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Consumer Behavior',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1999-11-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/7713c315-0db5-537b-b6e8-4f0ecaebdf23',
#     'word_count': 401,
#     'uri': 'nyt://article/7713c315-0db5-537b-b6e8-4f0ecaebdf23'},
#    {'abstract': 'Goldman, Sachs retail composite index shows growth in retail sales eased in October; sales in stores open at least a year, key comparison in industry, rose 4.1 percent, smallest increase in six months, leading many analysts and economists to predict possible drop-off in consumer buying; graph; chart (M)',
#     'web_url': 'https://www.nytimes.com/1999/11/05/business/october-data-disappointing-for-retailers.html',
#     'snippet': 'Goldman, Sachs retail composite index shows growth in retail sales eased in October; sales in stores open at least a year, key comparison in industry, rose 4.1 percent, smallest increase in six months, leading many analysts and economists to predi...',
#     'lead_paragraph': 'After six months of robust increases, the growth in retail sales eased in October, indicating a potential slowdown in consumer buying as the all-important holiday shopping season approaches.',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'October Data Disappointing For Retailers',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'October Data Disappointing For Retailers',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'GOLDMAN SACHS RETAIL COMPOSITE INDEX',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1999-11-05T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Leslie Kaufman',
#      'person': [{'firstname': 'Leslie',
#        'middlename': None,
#        'lastname': 'Kaufman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/ba58f750-e10f-5ebe-8c8d-eca5918080fe',
#     'word_count': 762,
#     'uri': 'nyt://article/ba58f750-e10f-5ebe-8c8d-eca5918080fe'},
#    {'abstract': 'Jim Frederick article on questions about just how momentous Internet commerce is going to become, questions that are hard to answer because of lack of kinds of historical patterns that are used to make forecasts about more mature industries; describes how Jupiter Communications and Forrester Research, two most prominent companies to have recognized Internet-certainty shortage, make prediction models; comments on forecasts that online advertising will be a $24 billion industry by 2003, 20 million households will trade stocks online that same year and consumers will have spent $6 billion online in holiday shopping by end of this month; drawing (M)',
#     'web_url': 'https://www.nytimes.com/1999/12/19/magazine/6-billion-online-holiday-sales-end-this-month-24-billion-internet-ads-2003-2.3.html',
#     'snippet': 'Jim Frederick article on questions about just how momentous Internet commerce is going to become, questions that are hard to answer because of lack of kinds of historical patterns that are used to make forecasts about more mature industries; descr...',
#     'lead_paragraph': "You don't need an expert to tell you we're living in the middle of a technological revolution. Everybody knows that the Internet is a big deal and getting bigger, and all those claims that its significance rivals that of the telephone, the railroad, the television and the automobile don't seem as delusional as they did a few years ago. Still, it's easy to wonder, to want to know, to need to know, exactly how momentous the Internet's impact will be. How big will, say, the online advertising industry get over the next three years? Just how many people will trade stocks online? And how much money will be spent shopping on the Web this holiday season, anyway?",
#     'print_section': '6',
#     'print_page': '70',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': '$6 Billion in Online Holiday Sales by the End of This Month! $24 Billion in Internet Ads by 2003! 2.3 Trillion E-Biz Predictions by 2010!',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': '$6 Billion in Online Holiday Sales by the End of This Month! $24 Billion in Internet Ads by 2003! 2.3 Trillion E-Biz Predictions by 2010!',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Forrester Research Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Jupiter Communications Inc',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'ADVERTISING', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Stocks and Bonds', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 6,
#       'major': 'N'}],
#     'pub_date': '1999-12-19T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Magazine Desk',
#     'section_name': 'Magazine',
#     'byline': {'original': 'By Jim Frederick',
#      'person': [{'firstname': 'Jim',
#        'middlename': None,
#        'lastname': 'Frederick',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/cad05e1e-e346-5584-b289-1827b139e47d',
#     'word_count': 3660,
#     'uri': 'nyt://article/cad05e1e-e346-5584-b289-1827b139e47d'},
#    {'abstract': 'Holiday season has proved to be far gloomier than expected for many Broadway shows; year after record-breaking box office and packed-to-the-rafters audiences, Broadway has had one of its slowest-selling weeks of year last week, with big drops in grosses and attendance; last show to open this century is Jackie Mason: Much Ado About Everything, which opened Dec 30, and last closing will be Epic Proportions, which folded on Dec 19; last show of 19th century was Ben-Hur, which opened Nov 29, 1899 at Broadway Theater; photo (M)',
#     'web_url': 'https://www.nytimes.com/1999/12/31/movies/on-stage-and-off.html',
#     'snippet': 'Holiday season has proved to be far gloomier than expected for many Broadway shows; year after record-breaking box office and packed-to-the-rafters audiences, Broadway has had one of its slowest-selling weeks of year last week, with big drops in g...',
#     'lead_paragraph': 'Of Holidays Not So Happy',
#     'print_section': 'E',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'ON STAGE AND OFF',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'ON STAGE AND OFF',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'New York City',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Theater', 'rank': 2, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'BEN-HUR (PLAY)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'JACKIE MASON: MUCH ADO ABOUT EVERYTHING',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'EPIC PROPORTIONS (PLAY)',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '1999-12-31T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Movies, Performing Arts/Weekend Desk',
#     'section_name': 'Movies',
#     'byline': {'original': 'By Jesse McKinley',
#      'person': [{'firstname': 'Jesse',
#        'middlename': None,
#        'lastname': 'McKinley',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/ae4d33e3-8289-51be-9ee3-d166258522c3',
#     'word_count': 982,
#     'uri': 'nyt://article/ae4d33e3-8289-51be-9ee3-d166258522c3'},
#    {'abstract': 'Nasdaq Composite Index rises 8.09 points to record 3,594.17 in its busiest day ever, led by Amazon.com Inc; Dow Jones industrial average rises 66.67, to 11,134.79; graphs (M)',
#     'web_url': 'https://www.nytimes.com/1999/12/10/business/the-markets-stocks-amazon-leads-nasdaq-to-record-on-extremely-busy-day.html',
#     'snippet': 'Nasdaq Composite Index rises 8.09 points to record 3,594.17 in its busiest day ever, led by Amazon.com Inc; Dow Jones industrial average rises 66.67, to 11,134.79; graphs (M)',
#     'lead_paragraph': 'The Nasdaq Composite Index rose to a record yesterday in the busiest day ever on the Nasdaq stock market, led by Amazon.com Inc., which benefited from optimism about holiday sales.',
#     'print_section': 'C',
#     'print_page': '7',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Amazon Leads Nasdaq to Record on Extremely Busy Day',
#      'kicker': 'THE MARKETS: STOCKS',
#      'content_kicker': None,
#      'print_headline': 'THE MARKETS: STOCKS; Amazon Leads Nasdaq to Record on Extremely Busy Day',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'AMAZON.COM INC',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Nasdaq Composite Index',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Stocks and Bonds', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Dow Jones Stock Average',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '1999-12-10T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/431ffb7a-dcf0-5656-ad06-a02029f95113',
#     'word_count': 541,
#     'uri': 'nyt://article/431ffb7a-dcf0-5656-ad06-a02029f95113'}],
#   'meta': {'hits': 26, 'offset': 0, 'time': 82}}}

# %%
articles_00 = api.search(q="holiday sales",begin_date=20001101, end_date=20001231)
articles_00
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Industry analysts say holiday shopping season seems to be among worst in decade, despite widespread markdowns and burst of last-minute buying; International Council of Shopping Centers reports sales at specialty stores in malls rose only 2.2 percent, down from 7.7 percent gain last year; sales are disappointing across almost all categories, with sales of bit-ticket, discretionary items particularly hard hit; graph of holiday sales; photo (M)',
#     'web_url': 'https://www.nytimes.com/2000/12/27/business/sales-in-holiday-season-rose-just-barely-over-last-year-s.html',
#     'snippet': 'Industry analysts say holiday shopping season seems to be among worst in decade, despite widespread markdowns and burst of last-minute buying; International Council of Shopping Centers reports sales at specialty stores in malls rose only 2.2 perce...',
#     'lead_paragraph': "Despite widespread markdowns and a burst of last-minute buying, this year's holiday shopping season is shaping up as among the worst in a decade, industry analysts said yesterday.",
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Sales in Holiday Season Rose, Just Barely, Over Last Year's",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Sales in Holiday Season Rose, Just Barely, Over Last Year's",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'International Council of Shopping Centers',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'SHOPPING CENTERS', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '2000-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Leslie Kaufman',
#      'person': [{'firstname': 'Leslie',
#        'middlename': None,
#        'lastname': 'Kaufman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/9eed856e-77ad-5db3-a756-068ad98f3f9f',
#     'word_count': 1254,
#     'uri': 'nyt://article/9eed856e-77ad-5db3-a756-068ad98f3f9f'},
#    {'abstract': "Gateway, second-largest US direct seller of computers, reports Thanksgiving sales 30 percent below last year's; warns that it will probably miss future quarterly earnings projections by wide margin (M)",
#     'web_url': 'https://www.nytimes.com/2000/11/30/business/technology-sales-of-pc-s-down-sharply-at-gateway.html',
#     'snippet': "Gateway, second-largest US direct seller of computers, reports Thanksgiving sales 30 percent below last year's; warns that it will probably miss future quarterly earnings projections by wide margin (M)",
#     'lead_paragraph': "Gateway, the nation's second-largest direct seller of computers, reported yesterday that its sales over the Thanksgiving weekend had plummeted 30 percent from last year's figures and warned that it would probably miss projections for quarterly earnings and revenue by a wide margin.",
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Sales of PC's Down Sharply At Gateway",
#      'kicker': 'TECHNOLOGY',
#      'content_kicker': None,
#      'print_headline': "TECHNOLOGY; Sales of PC's Down Sharply At Gateway",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Gateway Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Company Reports', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '2000-11-30T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Barnaby J. Feder',
#      'person': [{'firstname': 'Barnaby',
#        'middlename': 'J.',
#        'lastname': 'Feder',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/c209cb4c-2878-5f4e-8ce3-c578ec301b37',
#     'word_count': 696,
#     'uri': 'nyt://article/c209cb4c-2878-5f4e-8ce3-c578ec301b37'},
#    {'abstract': 'EToys and other Internet retailers are cutting prices as much as 75 percent to get rid of unsold merchandise after mixed holiday sales season; clearance sales are most important for companies that need more financing to stay in business (M)',
#     'web_url': 'https://www.nytimes.com/2000/12/26/business/internet-retailers-switch-to-clearing-merchandise.html',
#     'snippet': 'EToys and other Internet retailers are cutting prices as much as 75 percent to get rid of unsold merchandise after mixed holiday sales season; clearance sales are most important for companies that need more financing to stay in business (M)',
#     'lead_paragraph': 'EToys and other Internet retailers are cutting prices as much as 75 percent to get rid of unsold merchandise after a mixed holiday sales season.',
#     'print_section': 'C',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Internet Retailers Switch To Clearing Merchandise',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Internet Retailers Switch To Clearing Merchandise',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'eToys Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '2000-12-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/68e6e4ba-bc82-5699-9e0a-e73acd399db2',
#     'word_count': 444,
#     'uri': 'nyt://article/68e6e4ba-bc82-5699-9e0a-e73acd399db2'},
#    {'abstract': 'Last-minute sales, ingrained holiday tradition used largely as strategic tactic by retailers, have become increasingly desperate gambit because of slowing economy and steep loss in consumer appetite; vendors nationwide are slashing prices unusually early to rid themselves of unanticipated excess inventory; sales at specialty stores are down 6.2 percent for season as of December 10, despite strong sales reported day after Thanksgiving; anaylsts say it is hard to remember holiday season that offered bigger bargains to savvy shopper; photos (M)',
#     'web_url': 'https://www.nytimes.com/2000/12/18/business/early-bargains-aren-t-enticing-many-shoppers.html',
#     'snippet': 'Last-minute sales, ingrained holiday tradition used largely as strategic tactic by retailers, have become increasingly desperate gambit because of slowing economy and steep loss in consumer appetite; vendors nationwide are slashing prices unusuall...',
#     'lead_paragraph': "This year, Sears is throwing its after-Christmas sale before Christmas. The Gap has already slashed the prices of much of its signature leather collection in half. At Bath and Body Works, shower gels and bubble bath in this holiday's scents of Mulberry Spice and Candy Apple are on sale 3 for $24. And J. Crew stuck an insert into its catalogs that offered 50 percent off much of its fall merchandise to customers who shopped its Internet store.",
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Early Bargains Aren't Enticing Many Shoppers",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Early Bargains Aren't Enticing Many Shoppers",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Prices (Fares, Fees and Rates)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 5, 'major': 'N'}],
#     'pub_date': '2000-12-18T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Leslie Kaufman',
#      'person': [{'firstname': 'Leslie',
#        'middlename': None,
#        'lastname': 'Kaufman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/5a9e0038-c22c-56fb-93cc-1da332105447',
#     'word_count': 1267,
#     'uri': 'nyt://article/5a9e0038-c22c-56fb-93cc-1da332105447'},
#    {'abstract': "Online retail sales are estimated to rise of between 50 percent and 100 percent over last year, but fall short of many predictions; and a great percentage of Internet merchants' sales have been gleaned by online affiliates of conventional stores, to the dismay of Web-only merchants, many of whom will likely not survive; photo; list (M)",
#     'web_url': 'https://www.nytimes.com/2000/12/23/business/last-noel-for-some-dot-coms-traditional-chains-making-inroads-online-market.html',
#     'snippet': "Online retail sales are estimated to rise of between 50 percent and 100 percent over last year, but fall short of many predictions; and a great percentage of Internet merchants' sales have been gleaned by online affiliates of conventional stores, ...",
#     'lead_paragraph': 'For Internet merchants, this holiday season is bringing little joy, and not much comfort, either.',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Last Noel for Some Dot-Coms; Traditional Chains Making Inroads in the Online Market',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Last Noel for Some Dot-Coms; Traditional Chains Making Inroads in the Online Market',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Economic Conditions and Trends',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Bankruptcies', 'rank': 5, 'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 6, 'major': 'N'}],
#     'pub_date': '2000-12-23T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Saul Hansell',
#      'person': [{'firstname': 'Saul',
#        'middlename': None,
#        'lastname': 'Hansell',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/c58bc0fe-4d1f-51af-ae37-cae61fd0cf1a',
#     'word_count': 1444,
#     'uri': 'nyt://article/c58bc0fe-4d1f-51af-ae37-cae61fd0cf1a'},
#    {'abstract': " Early Flight Arrivals Often Mean Travelers Still Wait  These days, the scourge of air travel is often a flight that arrives late. But many passengers have begun to complain about something they find nearly as annoying: landing early. Officials say that annoyance is part of a broader problem of congestion at the nation's biggest airports. [Page A1.]    Decorations Find a New Market  Sales of Christmas kitsch are growing in China, where hotels, restaurants and shops bought nearly $50 million worth of holiday decorations this year. Christmas has been co-opted by the Communists as good for stimulating business, and it is already a bigger deal than New Year's Eve in China's cities. [C3.]",
#     'web_url': 'https://www.nytimes.com/2000/12/26/business/business-digest-152048.html',
#     'snippet': '',
#     'lead_paragraph': 'Early Flight Arrivals Often Mean Travelers Still Wait',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'BUSINESS DIGEST',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'BUSINESS DIGEST',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2000-12-26T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/a2fe0e1d-6bed-5eb5-acc5-833affee66d1',
#     'word_count': 526,
#     'uri': 'nyt://article/a2fe0e1d-6bed-5eb5-acc5-833affee66d1'},
#    {'abstract': 'Wal-Mart Stores Inc says profit rose 5.8 percent in its fiscal third quarter ended Oct 31; net income rose to $1.37 billion from $1.29 billion a year ago; sales rose 13 percent, to $45.7 billion from $40.4 billion; J C Penney reports $23 million loss in third quarter ended Oct 28 compared with profit of $142 million in year-earlier period; Home Depot Inc says profit rose 14 percent in fiscal third quarter ended Oct 29; net income rose to $650 million from $573 million; sales rose 17 percent, to $11.55 billion from $9.88 billion; Saks Inc says profit tumbled 97 percent in third quarter ended Oct 28; profit from operations fell to $1 million from $31.6 million a year earlier; sales rose 1.2 percent, to $1.57 billion from $1.55 billion (M)',
#     'web_url': 'https://www.nytimes.com/2000/11/15/business/wal-mart-earnings-up-5.8-as-j-c-penney-posts-a-loss.html',
#     'snippet': 'Wal-Mart Stores Inc says profit rose 5.8 percent in its fiscal third quarter ended Oct 31; net income rose to $1.37 billion from $1.29 billion a year ago; sales rose 13 percent, to $45.7 billion from $40.4 billion; J C Penney reports $23 million l...',
#     'lead_paragraph': "Wal-Mart Stores Inc. said yesterday that its fiscal third-quarter profit rose 5.8 percent as an expanded variety of groceries helped shield the company, the world's largest retailer, from slower consumer spending.",
#     'print_section': 'C',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Wal-Mart Earnings Up 5.8%, As J. C. Penney Posts a Loss',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Wal-Mart Earnings Up 5.8%, As J. C. Penney Posts a Loss',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Wal-Mart Stores Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Penney, J C, Co',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Home Depot Inc',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'organizations', 'value': 'Saks Inc', 'rank': 4, 'major': 'N'},
#      {'name': 'subject', 'value': 'Company Reports', 'rank': 5, 'major': 'N'}],
#     'pub_date': '2000-11-15T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/08ddc798-0c0a-5052-a69b-58a1a3f8869a',
#     'word_count': 420,
#     'uri': 'nyt://article/08ddc798-0c0a-5052-a69b-58a1a3f8869a'},
#    {'abstract': 'Montgomery Ward & Co, once the greatest American retailer and pioneer of many sales practices that became widely accepted, says that it will go out of business after 128 years; company, owned by General Electric, says it will close its 250 stores and dismiss 28,000 associates who run them in coming months; it files for Chapter 11 bankruptcy court protection for second and final time and eliminates 450 jobs immediately; photos (L)',
#     'web_url': 'https://www.nytimes.com/2000/12/29/business/montgomery-ward-to-close-its-doors.html',
#     'snippet': 'Montgomery Ward & Co, once the greatest American retailer and pioneer of many sales practices that became widely accepted, says that it will go out of business after 128 years; company, owned by General Electric, says it will close its 250 stores ...',
#     'lead_paragraph': 'Montgomery Ward & Company, once the greatest American retailer and the pioneer of many sales practices that became widely accepted, said yesterday that it would go out of business after 128 years.',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Montgomery Ward to Close Its Doors',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Montgomery Ward to Close Its Doors',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'General Electric Co',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'MONTGOMERY WARD & CO',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'LABOR', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Layoffs and Job Reductions',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Bankruptcies', 'rank': 6, 'major': 'N'}],
#     'pub_date': '2000-12-29T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Leslie Kaufman With Claudia H. Deutsch',
#      'person': [{'firstname': 'Leslie',
#        'middlename': 'Kaufman',
#        'lastname': 'With',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/0344084c-ac80-5c06-a83f-04899e4f8e55',
#     'word_count': 958,
#     'uri': 'nyt://article/0344084c-ac80-5c06-a83f-04899e4f8e55'},
#    {'abstract': 'Intel Corp cautions investors that its revenues will be flat for fourth quarter, not up 4 percent to 8 percent as it expected; cites order cancellations by large customers and general slowdowns in world economy; is latest addition to growing list of companies that face troubles in lethargic market for personal computers (M)',
#     'web_url': 'https://www.nytimes.com/2000/12/08/business/technology-intel-joins-industry-dirge-as-it-lowers-its-financial-projections.html',
#     'snippet': 'Intel Corp cautions investors that its revenues will be flat for fourth quarter, not up 4 percent to 8 percent as it expected; cites order cancellations by large customers and general slowdowns in world economy; is latest addition to growing list ...',
#     'lead_paragraph': "The Intel Corporation, the world's largest semiconductor maker, cautioned investors today that its revenues this quarter would fall short of projections. The company became the latest addition to the growing list of companies that face troubles in the lethargic market for personal computers.",
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Intel Joins Industry Dirge as It Lowers Its Financial Projections',
#      'kicker': 'TECHNOLOGY',
#      'content_kicker': None,
#      'print_headline': 'TECHNOLOGY; Intel Joins Industry Dirge as It Lowers Its Financial Projections',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Intel Corp',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Computer Chips', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '2000-12-08T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Chris Gaither',
#      'person': [{'firstname': 'Chris',
#        'middlename': None,
#        'lastname': 'Gaither',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/d21e3c41-e4d8-58c7-bd2e-5ae3fe0c287b',
#     'word_count': 863,
#     'uri': 'nyt://article/d21e3c41-e4d8-58c7-bd2e-5ae3fe0c287b'},
#    {'abstract': 'Ostentatious gift wraps are proving popular this year; examples cited; photo (M)',
#     'web_url': 'https://www.nytimes.com/2000/12/10/business/business-this-money-doesn-t-just-talk-it-wraps.html',
#     'snippet': 'Ostentatious gift wraps are proving popular this year; examples cited; photo (M)',
#     'lead_paragraph': "IT may be the thought that counts and what's inside that matters, but you would never know that this holiday season.",
#     'print_section': '3',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "This Money Doesn't Just Talk. It Wraps.",
#      'kicker': 'BUSINESS',
#      'content_kicker': None,
#      'print_headline': "BUSINESS; This Money Doesn't Just Talk. It Wraps.",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Containers and Packaging',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Gifts', 'rank': 2, 'major': 'N'}],
#     'pub_date': '2000-12-10T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Money and Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Andrea Higbie',
#      'person': [{'firstname': 'Andrea',
#        'middlename': None,
#        'lastname': 'Higbie',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/f19135f9-1c0b-56c2-86ab-8226b7a2a174',
#     'word_count': 585,
#     'uri': 'nyt://article/f19135f9-1c0b-56c2-86ab-8226b7a2a174'}],
#   'meta': {'hits': 18, 'offset': 0, 'time': 111}}}

# %%
articles_01 = api.search(q="holiday sales",begin_date=20011101, end_date=20011231)
articles_01
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': "Article discusses bleak holiday sales outlook for book publishers; with terrorism, war and threat of recession dominating consumers' attention this fall, major publishers are having decreases in their sales of as much as 15 percent from last year's lackluster levels; photo (M)",
#     'web_url': 'https://www.nytimes.com/2001/11/19/business/holiday-sales-outlook-roils-book-business.html',
#     'snippet': "Article discusses bleak holiday sales outlook for book publishers; with terrorism, war and threat of recession dominating consumers' attention this fall, major publishers are having decreases in their sales of as much as 15 percent from last year'...",
#     'lead_paragraph': "When the profitable life of a new hardcover book comes to an end, its publisher usually consigns it to an inconspicuous office building on Fifth Avenue near 26th Street in Manhattan that is the graveyard of unsold books. It is the headquarters for several companies that sell publishers' leftover copies back to bookstores for an undignified afterlife in the deeply discounted remainder bin.",
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Holiday Sales Outlook Roils Book Business',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Holiday Sales Outlook Roils Book Business',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'New York City',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Washington (DC)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'glocations', 'value': 'AFGHANISTAN', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'World Trade Center (NYC)',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'AIRLINES AND AIRPLANES',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States International Relations',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 8,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Books and Literature',
#       'rank': 9,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'INDUSTRY PROFILES',
#       'rank': 10,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Hijacking', 'rank': 11, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 12, 'major': 'N'},
#      {'name': 'subject', 'value': 'Terrorism', 'rank': 13, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'UNITED STATES ARMAMENT AND DEFENSE',
#       'rank': 14,
#       'major': 'N'}],
#     'pub_date': '2001-11-19T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By David D. Kirkpatrick',
#      'person': [{'firstname': 'David',
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/26074576-c177-5a9c-b67d-19d1f131f841',
#     'word_count': 1200,
#     'uri': 'nyt://article/26074576-c177-5a9c-b67d-19d1f131f841'},
#    {'abstract': 'BizRate.com reports 29 percent rise in Internet sales, to $2.13 billion, during two weeks from Nov 19 through Dec 2, helped by price cuts and free shipping (S)',
#     'web_url': 'https://www.nytimes.com/2001/12/04/business/technology-briefing-internet-online-holiday-sales-rise-29.html',
#     'snippet': 'BizRate.com reports 29 percent rise in Internet sales, to $2.13 billion, during two weeks from Nov 19 through Dec 2, helped by price cuts and free shipping (S)',
#     'lead_paragraph': 'Internet sales rose 29 percent in the first two weeks of the holiday season, helped by price cuts and free shipping, analysts said yesterday. Sales from Nov. 19 through Dec. 2 totaled $2.13 billion, up from $1.65 billion for the corresponding period last year, according to BizRate.com, which tracks transactions at 2,000 online merchants. Shoppers placed 16.3 million orders at Internet stores, buying mainly electronics, toys and computer hardware, the company said. Many stores are offering free shipping, including Amazon.com, the largest Internet retailer. The company, which is based in Seattle, is selling an Apex DVD player that had been priced at $119.95 for $99.99. JCPenney.com is advertising 25 percent off regular prices for clothing and shoes. BizRate.com is forecasting online sales will rise 31 percent in the six-week holiday sales period.',
#     'print_section': 'C',
#     'print_page': '10',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Technology Briefing | Internet: Online Holiday Sales Rise 29%',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Technology Briefing | Internet: Online Holiday Sales Rise 29%',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Bizrate.com',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Prices (Fares, Fees and Rates)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Discount Selling', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 6,
#       'major': 'N'}],
#     'pub_date': '2001-12-04T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/657b4f7e-2209-5d8b-bd7e-4312c02b35c5',
#     'word_count': 132,
#     'uri': 'nyt://article/657b4f7e-2209-5d8b-bd7e-4312c02b35c5'},
#    {'abstract': "Last-minute shopping surge may have given nation's retailers and economy small boost; sales gains, spurred by sharp price cuts, will add little to retailers' profits; TeleCheck Services Inc reports pre-Christmas sales nationwide in stores opened at least year rose 2.2 percent over 2000, smallest rise since 1997; Wal-Mart Stores reports sales rose some 6 percent; other discounters also report strong gains; photos (M)",
#     'web_url': 'https://www.nytimes.com/2001/12/27/business/late-shopping-gives-retailers-a-slight-boost.html',
#     'snippet': "Last-minute shopping surge may have given nation's retailers and economy small boost; sales gains, spurred by sharp price cuts, will add little to retailers' profits; TeleCheck Services Inc reports pre-Christmas sales nationwide in stores opened a...",
#     'lead_paragraph': "A surge of last-minute shopping may have given the nation's retailers and the economy a small boost, according to several reports on holiday sales released yesterday.",
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Late Shopping Gives Retailers A Slight Boost',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Late Shopping Gives Retailers A Slight Boost',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Wal-Mart Stores Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'TELECHECK SERVICES INC',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Prices (Fares, Fees and Rates)',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '2001-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Leslie Kaufman',
#      'person': [{'firstname': 'Leslie',
#        'middlename': None,
#        'lastname': 'Kaufman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/b3cc4fe9-b5a8-5353-83f2-59278fd29527',
#     'word_count': 976,
#     'uri': 'nyt://article/b3cc4fe9-b5a8-5353-83f2-59278fd29527'},
#    {'abstract': 'Fears about anthrax spreading by mail have not lowered holiday sales of Hallmark Cards; they are 2 to 4 percent ahead of same period in 2000 (S)',
#     'web_url': 'https://www.nytimes.com/2001/12/23/business/business-diary-greetings-without-fear.html',
#     'snippet': 'Fears about anthrax spreading by mail have not lowered holiday sales of Hallmark Cards; they are 2 to 4 percent ahead of same period in 2000 (S)',
#     'lead_paragraph': "Fears about anthrax in the mail apparently have not hurt holiday card sales at Hallmark Cards, the nation's largest greeting card company. Hallmark, based in Kansas City, Mo., said last week that sales were up 2 to 4 percent since Thanksgiving, compared with the corresponding period last year.",
#     'print_section': '3',
#     'print_page': '6',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Greetings Without Fear',
#      'kicker': 'BUSINESS: DIARY',
#      'content_kicker': None,
#      'print_headline': 'BUSINESS: DIARY; Greetings Without Fear',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Hallmark Cards Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Biological and Chemical Warfare',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'ANTHRAX', 'rank': 4, 'major': 'N'},
#      {'name': 'subject', 'value': 'Greeting Cards', 'rank': 5, 'major': 'N'},
#      {'name': 'subject', 'value': 'Postal Service', 'rank': 6, 'major': 'N'},
#      {'name': 'subject', 'value': 'Terrorism', 'rank': 7, 'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 8, 'major': 'N'}],
#     'pub_date': '2001-12-23T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Money and Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'Compiled by Vivian Marino',
#      'person': [{'firstname': 'Vivian',
#        'middlename': None,
#        'lastname': 'Marino',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/a5c47f64-bc2b-5c81-b40a-6004047ffde9',
#     'word_count': 98,
#     'uri': 'nyt://article/a5c47f64-bc2b-5c81-b40a-6004047ffde9'},
#    {'abstract': " Late Surge in Holiday Sales May Have Lifted Retailers  A surge of last-minute shopping may have given the nation's retailers and the economy a small boost, according to several reports on holiday sales.    The late sales gains will not add much to retailers' profits because most of the increases came after deep price cuts. Still, analysts said the discounts that moved merchandise out of the stores should be good for the overall economy. [Page A1.]",
#     'web_url': 'https://www.nytimes.com/2001/12/27/business/business-digest-861154.html',
#     'snippet': '',
#     'lead_paragraph': 'Late Surge in Holiday Sales May Have Lifted Retailers',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'BUSINESS DIGEST',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'BUSINESS DIGEST',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2001-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/6f568f3a-eb92-57fa-b802-6398c8e1e73c',
#     'word_count': 621,
#     'uri': 'nyt://article/6f568f3a-eb92-57fa-b802-6398c8e1e73c'},
#    {'abstract': 'E-Commerce Report column notes that majority of big retailers are optimistic concerning online holiday sales; photo (M)',
#     'web_url': 'https://www.nytimes.com/2001/11/19/business/e-commerce-report-some-big-retailers-are-optimistic-about-online-wish-lists-high.html',
#     'snippet': 'E-Commerce Report column notes that majority of big retailers are optimistic concerning online holiday sales; photo (M)',
#     'lead_paragraph': 'SINCE the earliest days of e-commerce, the big question has been whether the Internet spawns new buying behavior, or whether consumers simply transfer old habits online.',
#     'print_section': 'C',
#     'print_page': '8',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'E-Commerce Report; Some big retailers are optimistic about online wish lists, a high-mortality sector.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'E-Commerce Report; Some big retailers are optimistic about online wish lists, a high-mortality sector.',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'HOLIDAY TRADE',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2001-11-19T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bob Tedeschi',
#      'person': [{'firstname': 'Bob',
#        'middlename': None,
#        'lastname': 'Tedeschi',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/6da2f74b-209f-5243-bc49-09825da6fa06',
#     'word_count': 1198,
#     'uri': 'nyt://article/6da2f74b-209f-5243-bc49-09825da6fa06'},
#    {'abstract': ' Japan Details Sea Battle  Japan Coast Guard officials say a vessel suspected of being a North Korean spy boat fired rockets at two of its ships.   PAGE A3    A Christmas Quarrel  Israel barred Yasir Arafat from religious ceremonies in Bethlehem, and Palestinian gunmen shot an Israeli motorist.   PAGE A4',
#     'web_url': 'https://www.nytimes.com/2001/12/25/nyregion/inside-834696.html',
#     'snippet': '',
#     'lead_paragraph': 'Japan Details Sea Battle',
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'INSIDE',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'INSIDE',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2001-12-25T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Metropolitan Desk',
#     'section_name': 'New York',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Summary',
#     '_id': 'nyt://article/3332741d-b500-5a53-86ad-f1266f80cd1a',
#     'word_count': 104,
#     'uri': 'nyt://article/3332741d-b500-5a53-86ad-f1266f80cd1a'},
#    {'abstract': 'Technology Briefing',
#     'web_url': 'https://www.nytimes.com/2001/12/04/technology/technology-briefing.html',
#     'snippet': 'Technology Briefing',
#     'lead_paragraph': ' SOFTWARE ',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Technology Briefing',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Technology Briefing',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'Xinjiang (China)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Nortel Networks Corporation',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Romero, Simon', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Computer Chips', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Telephones and Telecommunications',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Cellular Telephones',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Company Reports', 'rank': 7, 'major': 'N'}],
#     'pub_date': '2001-12-04T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Technology',
#     'section_name': 'Technology',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/26232c25-f2d7-542f-ab86-3f5d13a75e22',
#     'word_count': 1033,
#     'uri': 'nyt://article/26232c25-f2d7-542f-ab86-3f5d13a75e22'},
#    {'abstract': 'Shoppers crowd stores day after Christmas, searching for bargains and big discounts, but are often disappointed with markdowns; in some areas, stores are empty; photo (M)',
#     'web_url': 'https://www.nytimes.com/2001/12/27/business/locally-big-discounts-draw-crowds-and-dismay.html',
#     'snippet': 'Shoppers crowd stores day after Christmas, searching for bargains and big discounts, but are often disappointed with markdowns; in some areas, stores are empty; photo (M)',
#     'lead_paragraph': "Lisa Blum braved the crowds at Bloomingdale's flagship Manhattan store yesterday to stock up on Christmas ornaments, some marked down by as much as 75 percent. Then she planned to head over to the linen department to pick up some sheets she had spotted before the holiday, which were now on sale.",
#     'print_section': 'C',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Locally, Big Discounts Draw Crowds and Dismay',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Locally, Big Discounts Draw Crowds and Dismay',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 2, 'major': 'N'}],
#     'pub_date': '2001-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Terry Pristin',
#      'person': [{'firstname': 'Terry',
#        'middlename': None,
#        'lastname': 'Pristin',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/1df253cc-2961-534e-a85c-ac01aebd964d',
#     'word_count': 789,
#     'uri': 'nyt://article/1df253cc-2961-534e-a85c-ac01aebd964d'},
#    {'abstract': 'Holiday sales show signs of being much stronger than retailers expected, and store inventories now emerges as defining issue for retailers and manufacturers; merchants scaled back markedly on orders last spring, sensing sharp economic downturn, and Sept 11 terrorist attacks further discouraged them, leading them to cancel or return goods and scuttle reorder plans; current conditions suggest possibility of widespread shortages during coming weeks; photos; charts (M)',
#     'web_url': 'https://www.nytimes.com/2001/12/09/business/a-brighter-holiday-if-the-goods-hold-out.html',
#     'snippet': 'Holiday sales show signs of being much stronger than retailers expected, and store inventories now emerges as defining issue for retailers and manufacturers; merchants scaled back markedly on orders last spring, sensing sharp economic downturn, an...',
#     'lead_paragraph': "IF you visit garnethill.com, the online arm of the catalog retailer Garnet Hill, don't expect to buy those cute suede slippers from Italy. Every size but 7 is sold out. The same goes for those handsome suede shirts, one of the company's recommended holiday gifts.",
#     'print_section': '3',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A Brighter Holiday (If the Goods Hold Out)',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A Brighter Holiday (If the Goods Hold Out)',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'New York City',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Washington (DC)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'World Trade Center (NYC)',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'AIRLINES AND AIRPLANES',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Shortages', 'rank': 6, 'major': 'N'},
#      {'name': 'subject', 'value': 'Hijacking', 'rank': 7, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Economic Conditions and Trends',
#       'rank': 8,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Terrorism', 'rank': 9, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 10,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 11, 'major': 'N'}],
#     'pub_date': '2001-12-09T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Money and Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Stephanie Strom',
#      'person': [{'firstname': 'Stephanie',
#        'middlename': None,
#        'lastname': 'Strom',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/cc129cc3-f811-51b7-9871-4a3e187c5471',
#     'word_count': 2134,
#     'uri': 'nyt://article/cc129cc3-f811-51b7-9871-4a3e187c5471'}],
#   'meta': {'hits': 24, 'offset': 0, 'time': 108}}}

# %%
articles_02 = api.search(q="holiday sales",begin_date=20021101, end_date=20021231)
articles_02
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Roundup of Manhattan stores featuring bargain prices and pre-holiday sales on home furnishings and furniture; photos (M)',
#     'web_url': 'https://www.nytimes.com/2002/12/19/garden/let-the-after-holiday-sales-begin.html',
#     'snippet': 'Roundup of Manhattan stores featuring bargain prices and pre-holiday sales on home furnishings and furniture; photos (M)',
#     'lead_paragraph': "THERE was a time when ''January'' and ''sales'' were synonymous. But this year there are plenty of bargains in December. Furniture, lighting, accessories and rugs are now available at deep discounts.",
#     'print_section': 'F',
#     'print_page': '9',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Let the After-Holiday Sales Begin',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Let the After-Holiday Sales Begin',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'New York City',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Prices (Fares, Fees and Rates)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Gifts', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Furniture', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Home Furnishings',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '2002-12-19T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'House & Home/Style Desk',
#     'section_name': 'Home & Garden',
#     'byline': {'original': 'By Marianne Rohrlich',
#      'person': [{'firstname': 'Marianne',
#        'middlename': None,
#        'lastname': 'Rohrlich',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/92d87b05-dbde-55df-88e0-7da964cf65fb',
#     'word_count': 455,
#     'uri': 'nyt://article/92d87b05-dbde-55df-88e0-7da964cf65fb'},
#    {'abstract': "Retailers' hoped-for last minute shopping rush in days before Christmas never arrived this year; some analysts are predicting worst retail Christmas sales in decades; retailers were already bracing themselves, knowing there are six fewer shopping days this year between Thanksgiving and Christmas; International Council of Shopping Centers statistics show holiday sales increases in last three years have steadily shrunk--from 9.5 percent increase in 1999 to just 4 percent gain in 2000 and slim 2.3 percent jump last year; one analyst estimates that more than half of merchandise in most major stores has been reduced this holiday season; photo; graph (M)",
#     'web_url': 'https://www.nytimes.com/2002/12/25/business/holiday-sales-may-climb-an-anemic-1-this-year.html',
#     'snippet': "Retailers' hoped-for last minute shopping rush in days before Christmas never arrived this year; some analysts are predicting worst retail Christmas sales in decades; retailers were already bracing themselves, knowing there are six fewer shopping ...",
#     'lead_paragraph': 'Fabian Mira, a 32-year-old father of two daughters, was rushing through Times Square yesterday, clutching three shopping bags full of Barbie dolls and a Power Ranger Ninja Storm (for a nephew). Christmas shopping, he said, had made him sad.',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Holiday Sales May Climb An Anemic 1% This Year',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Holiday Sales May Climb An Anemic 1% This Year',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'International Council of Shopping Centers',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 3, 'major': 'N'}],
#     'pub_date': '2002-12-25T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Tracie Rozhon',
#      'person': [{'firstname': 'Tracie',
#        'middlename': None,
#        'lastname': 'Rozhon',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/eea6fae6-eec9-5c71-b2ed-208ea798b0cb',
#     'word_count': 937,
#     'uri': 'nyt://article/eea6fae6-eec9-5c71-b2ed-208ea798b0cb'},
#    {'abstract': "This year's holiday season is worst in many years for retail stores; retail analyst Michael P Niemira says growth in United States retail sales for months of Nov and Dec, at 1.5 percent, is lowest since at least 1970; spokesman for National Retail Federation, known for its upbeat forecasts, lowers its estimate of percent growth for Dec to 3.5 percent; Wal-Mart Stores, nation's biggest retailer, lowers its estimates of Dec sales growth to 2 percent to 3 percent, rather than 3 percent to 5 percent it was forecasting earlier; last year, Wal-Mart posed Dec sales growth of 8.1 percent; idea that even Wal-Mart is struggling is taken as sign of wider problems; worry about economy and about impending war with Iraq and new terrorist attacks have kept many shoppers from buying, even with deep discounts on many items; percentage of consumers giving gift certificates as presents this holiday season soared from previous years, to 54 percent; photos; graph (M)",
#     'web_url': 'https://www.nytimes.com/2002/12/27/business/growth-in-sales-for-holiday-period-is-lowest-in-years.html',
#     'snippet': "This year's holiday season is worst in many years for retail stores; retail analyst Michael P Niemira says growth in United States retail sales for months of Nov and Dec, at 1.5 percent, is lowest since at least 1970; spokesman for National Retail...",
#     'lead_paragraph': "After examining sales figures from the last frenzied hours before Christmas, experts yesterday declared this year's holiday season the worst in many years.",
#     'print_section': 'A',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'GROWTH IN SALES FOR HOLIDAY PERIOD IS LOWEST IN YEARS',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'GROWTH IN SALES FOR HOLIDAY PERIOD IS LOWEST IN YEARS',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'Iraq',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Wal-Mart Stores Inc',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'National Retail Federation',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'NIEMIRA, MICHAEL P',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 5, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States International Relations',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Economy',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Prices (Fares, Fees and Rates)',
#       'rank': 8,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Discount Selling', 'rank': 9, 'major': 'N'},
#      {'name': 'subject', 'value': 'Terrorism', 'rank': 10, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 11,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 12, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'UNITED STATES ARMAMENT AND DEFENSE',
#       'rank': 13,
#       'major': 'N'}],
#     'pub_date': '2002-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Constance L. Hays',
#      'person': [{'firstname': 'Constance',
#        'middlename': 'L.',
#        'lastname': 'Hays',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/85fd5a3b-521f-5ba1-9563-cdcb0dcccd35',
#     'word_count': 1139,
#     'uri': 'nyt://article/85fd5a3b-521f-5ba1-9563-cdcb0dcccd35'},
#    {'abstract': 'Wal-Mart Stores says that December sales are near low end of its forecast of increase of 3 percent to 5 percent (S)',
#     'web_url': 'https://www.nytimes.com/2002/12/24/business/company-news-wal-mart-says-december-sales-on-low-end-of-forecast.html',
#     'snippet': 'Wal-Mart Stores says that December sales are near low end of its forecast of increase of 3 percent to 5 percent (S)',
#     'lead_paragraph': "Wal-Mart Stores said yesterday that December sales are near the low end of its forecast of an increase of 3 percent to 5 percent. Sales at Wal-Mart's discount stores lagged behind the estimate, as fewer shoppers visited the company's stores, based on results for the week ended Friday, the company said. Wal-Mart said predicting total holiday sales was still difficult because there are fewer shopping days from Thanksgiving to Christmas this year and more shoppers are buying later.",
#     'print_section': 'C',
#     'print_page': '3',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'WAL-MART SAYS DECEMBER SALES ON LOW END OF FORECAST',
#      'kicker': 'COMPANY NEWS',
#      'content_kicker': None,
#      'print_headline': 'COMPANY NEWS; WAL-MART SAYS DECEMBER SALES ON LOW END OF FORECAST',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Wal-Mart Stores Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2002-12-24T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/74202c74-319c-5688-9e43-3d0223c8b8f1',
#     'word_count': 78,
#     'uri': 'nyt://article/74202c74-319c-5688-9e43-3d0223c8b8f1'},
#    {'abstract': "Early holiday reports indicate that sales of CD's continue to decline despite substantial marketing blitz designed by music companies to reverse diminishing retail results; photo (M)",
#     'web_url': 'https://www.nytimes.com/2002/12/23/business/media-despite-a-marketing-blitz-cd-sales-continue-to-slide.html',
#     'snippet': "Early holiday reports indicate that sales of CD's continue to decline despite substantial marketing blitz designed by music companies to reverse diminishing retail results; photo (M)",
#     'lead_paragraph': 'Despite efforts by record executives to stanch declining CD sales by releasing a cavalcade of big-name artists during the critical Christmas shopping season, early sales figures show an already struggling industry may now be in even worse shape.',
#     'print_section': 'C',
#     'print_page': '9',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Despite a Marketing Blitz, CD Sales Continue to Slide',
#      'kicker': 'MEDIA',
#      'content_kicker': None,
#      'print_headline': 'MEDIA; Despite a Marketing Blitz, CD Sales Continue to Slide',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Music', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'ADVERTISING', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'MARKETING AND MERCHANDISING',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Compact Discs', 'rank': 5, 'major': 'N'}],
#     'pub_date': '2002-12-23T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Lynette Holloway',
#      'person': [{'firstname': 'Lynette',
#        'middlename': None,
#        'lastname': 'Holloway',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/5af200e8-ce44-5430-b761-6c49ba73cf5d',
#     'word_count': 885,
#     'uri': 'nyt://article/5af200e8-ce44-5430-b761-6c49ba73cf5d'},
#    {'abstract': 'Online retailers are having their best year ever, but exactly how much better is subject to dispute; comScore puts online sales since Nov 1 at $8.4 billion as of Dec 20, 19 percent jump from comparable period of 2001, but not 30 percent increase it predicted just a few weeks ago; BizRate, however, says sales figure as of Dec 20 was $11.3 billion, 40 percent increase from 2001; analysts differ on whether to go with conservative or more bullish estimates; online merchants seem to be doing good job of managing investories and filling orders; sales at brick-and-mortar retail stores are dominated by clothes, toys and books, music and movies, nearly reverse order of online sales; photo (M)',
#     'web_url': 'https://www.nytimes.com/2002/12/23/business/e-commerce-report-online-sales-are-up-for-holiday-but-question-just-much.html',
#     'snippet': 'Online retailers are having their best year ever, but exactly how much better is subject to dispute; comScore puts online sales since Nov 1 at $8.4 billion as of Dec 20, 19 percent jump from comparable period of 2001, but not 30 percent increase i...',
#     'lead_paragraph': 'While ordinary stores and catalog merchants have struggled for sales growth this holiday season, online retailers are having their best year yet. The main question late last week was how good was good.',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'E-Commerce Report; Online Sales Are Up for Holiday, But the Question Is Just How Much',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'E-Commerce Report; Online Sales Are Up for Holiday, But the Question Is Just How Much',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'COMSCORE MEDIA METRIX',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Bizrate.com',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 3, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '2002-12-23T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bob Tedeschi',
#      'person': [{'firstname': 'Bob',
#        'middlename': None,
#        'lastname': 'Tedeschi',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/95fc9f36-bd12-5f8c-a2da-e948509d860a',
#     'word_count': 1381,
#     'uri': 'nyt://article/95fc9f36-bd12-5f8c-a2da-e948509d860a'},
#    {'abstract': 'Bookseller Barnes & Noble says it will not meet its holiday sales forecasts; its stock price drops 18 percent (M)',
#     'web_url': 'https://www.nytimes.com/2002/12/20/business/barnes-noble-says-holiday-season-won-t-meet-forecast.html',
#     'snippet': 'Bookseller Barnes & Noble says it will not meet its holiday sales forecasts; its stock price drops 18 percent (M)',
#     'lead_paragraph': 'Barnes & Noble, the largest bookseller in the country, said yesterday that it would miss its previous forecasts for the holiday shopping season because of disappointing sales of books and video games, providing the latest ominous signs for both businesses this year.',
#     'print_section': 'C',
#     'print_page': '7',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "Barnes & Noble Says Holiday Season Won't Meet Forecast",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "Barnes & Noble Says Holiday Season Won't Meet Forecast",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'BARNES & NOBLE',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Books and Literature',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Book Trade', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2002-12-20T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By David D. Kirkpatrick',
#      'person': [{'firstname': 'David',
#        'middlename': None,
#        'lastname': None,
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/e86d3dfc-0d8e-5679-b705-1ee5daa47937',
#     'word_count': 600,
#     'uri': 'nyt://article/e86d3dfc-0d8e-5679-b705-1ee5daa47937'},
#    {'abstract': 'Editorial on anemic pre-Christmas consumer spending, which may be bolstered by stronger post-Christmas gift buying; sees danger that businesses and consumers may drastically alter behavior in anticipation of war with Iraq; cautions policy makers against exaggerating sluggishness of holiday sales to advance tax cuts (M)',
#     'web_url': 'https://www.nytimes.com/2002/12/28/opinion/a-mildly-merry-christmas.html',
#     'snippet': 'Editorial on anemic pre-Christmas consumer spending, which may be bolstered by stronger post-Christmas gift buying; sees danger that businesses and consumers may drastically alter behavior in anticipation of war with Iraq; cautions policy makers a...',
#     'lead_paragraph': 'The holiday season is the make-or-break moment for the retail segment of the American economy. This particular season has brought little cheer. In keeping with the generally anemic recovery of the economy as a whole, holiday sales figures have so far registered the smallest year-to-year increase in three decades.',
#     'print_section': 'A',
#     'print_page': '18',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'A Mildly Merry Christmas',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A Mildly Merry Christmas',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'Iraq',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'ATOMIC WEAPONS', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Biological and Chemical Warfare',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States International Relations',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Taxation', 'rank': 5, 'major': 'N'},
#      {'name': 'subject', 'value': 'Editorials', 'rank': 6, 'major': 'N'},
#      {'name': 'subject', 'value': 'Terrorism', 'rank': 7, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 8,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 9, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'UNITED STATES ARMAMENT AND DEFENSE',
#       'rank': 10,
#       'major': 'N'}],
#     'pub_date': '2002-12-28T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Editorial Desk',
#     'section_name': 'Opinion',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Editorial',
#     '_id': 'nyt://article/2c4506a0-d56e-5723-8d2d-aad6454a21ac',
#     'word_count': 550,
#     'uri': 'nyt://article/2c4506a0-d56e-5723-8d2d-aad6454a21ac'},
#    {'abstract': "Record companies release unusually heavy blitz of CD's by big-name artists in hopes of drawing big holiday sales; strategy could turn counterproductive if such large number of new releases cancel each other out; photos (M)",
#     'web_url': 'https://www.nytimes.com/2002/11/18/business/media-cd-s-crowd-holiday-market.html',
#     'snippet': "Record companies release unusually heavy blitz of CD's by big-name artists in hopes of drawing big holiday sales; strategy could turn counterproductive if such large number of new releases cancel each other out; photos (M)",
#     'lead_paragraph': 'Stung by an alarming decline in CD sales, record executives began releasing an unusually heavy blitz of big-name artists last week in hopes of drawing big holiday sales.',
#     'print_section': 'C',
#     'print_page': '9',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "CD's Crowd Holiday Market",
#      'kicker': 'MEDIA',
#      'content_kicker': None,
#      'print_headline': "MEDIA; CD's Crowd Holiday Market",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'RECORDINGS (AUDIO)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Music', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 3, 'major': 'N'}],
#     'pub_date': '2002-11-18T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Lynette Holloway',
#      'person': [{'firstname': 'Lynette',
#        'middlename': None,
#        'lastname': 'Holloway',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/5a1a6538-e37e-55f9-b912-90ec503ceb6b',
#     'word_count': 923,
#     'uri': 'nyt://article/5a1a6538-e37e-55f9-b912-90ec503ceb6b'},
#    {'abstract': 'Some malls draw crowds for post-holiday sales, but one expert says that shoppers did not flock to Manhattan stores in same numbers they did when economy was stronger (S)',
#     'web_url': 'https://www.nytimes.com/2002/12/27/business/post-christmas-bargains-fail-to-draw-big-crowds.html',
#     'snippet': 'Some malls draw crowds for post-holiday sales, but one expert says that shoppers did not flock to Manhattan stores in same numbers they did when economy was stronger (S)',
#     'lead_paragraph': "Rosa Delanuez, a City College student, was toting several shopping bags at Macy's flagship store in Manhattan yesterday because she and her close relatives have a holiday tradition: give a few small gifts on Christmas Day, but do the bulk of the shopping afterward and save the best presents for Jan. 6, the Day of the Three Kings.",
#     'print_section': 'C',
#     'print_page': '4',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Post-Christmas Bargains Fail to Draw Big Crowds',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Post-Christmas Bargains Fail to Draw Big Crowds',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'New York City',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Prices (Fares, Fees and Rates)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 5, 'major': 'N'}],
#     'pub_date': '2002-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Terry Pristin',
#      'person': [{'firstname': 'Terry',
#        'middlename': None,
#        'lastname': 'Pristin',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/2e58b5b2-ba23-5d50-bf09-60349738f529',
#     'word_count': 638,
#     'uri': 'nyt://article/2e58b5b2-ba23-5d50-bf09-60349738f529'}],
#   'meta': {'hits': 22, 'offset': 0, 'time': 110}}}

# %%
articles_03 = api.search(q="holiday sales",begin_date=20031101, end_date=20031231)
articles_03
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': "Poring over the weekend sales figures, retail stock analysts threw cold water yesterday on some of the more optimistic projections for the kickoff to the holiday shopping season.      ''We believe the results over the weekend were mixed at best, and certainly less robust than last year,'' wrote Todd D. Slater, a retail stocks analyst at Lazard Fr&#232;res & Company.  ",
#     'web_url': 'https://www.nytimes.com/2003/12/02/business/retail-analysts-yawn-at-early-holiday-sales.html',
#     'snippet': '',
#     'lead_paragraph': 'Poring over the weekend sales figures, retail stock analysts threw cold water yesterday on some of the more optimistic projections for the kickoff to the holiday shopping season.',
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Retail Analysts Yawn at Early Holiday Sales',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Retail Analysts Yawn at Early Holiday Sales',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2003-12-02T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Tracie Rozhon',
#      'person': [{'firstname': 'Tracie',
#        'middlename': None,
#        'lastname': 'Rozhon',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/4a092e97-22f2-5651-b5ad-886b41b46ffc',
#     'word_count': 828,
#     'uri': 'nyt://article/4a092e97-22f2-5651-b5ad-886b41b46ffc'},
#    {'abstract': 'Holiday sales on Black Friday, day after Thanksgiving, are described as good but not spectacular; National Retail Federation is expecting 5.7 percent increase in overall holidays sales from 2002 level, increase from 2.1 percent gain registered last year; average consumer is expected to spend $671 on holiday purchases, compared with $648 in 2002; photo (M)',
#     'web_url': 'https://www.nytimes.com/2003/11/29/business/they-re-off-and-shopping-but-seeking-sales.html',
#     'snippet': 'Holiday sales on Black Friday, day after Thanksgiving, are described as good but not spectacular; National Retail Federation is expecting 5.7 percent increase in overall holidays sales from 2002 level, increase from 2.1 percent gain registered las...',
#     'lead_paragraph': "Holiday shoppers, intent on bargains, descended on America's malls yesterday, but spent only slightly more than they did last year, according to reports from retailers and analysts.",
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': "They're Off and Shopping, but Seeking Sales",
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': "They're Off and Shopping, but Seeking Sales",
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'National Retail Federation',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Consumer Behavior',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 5, 'major': 'N'}],
#     'pub_date': '2003-11-29T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Tracie Rozhon',
#      'person': [{'firstname': 'Tracie',
#        'middlename': None,
#        'lastname': 'Rozhon',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/5e7f2874-d5e8-5867-a69e-3bdb5f1111fd',
#     'word_count': 1339,
#     'uri': 'nyt://article/5e7f2874-d5e8-5867-a69e-3bdb5f1111fd'},
#    {'abstract': "Estimates of Christmas holiday sales gain this year range from 3.5 percent to 5.7 percent over last year's disappointing holiday season; analysts say 2003 sales will be about average for holiday shopping season, rather than above average as many retailers had projected; some retailers, such as Wal-Mart Stores, expect only modest growth from last year's sales, while luxury retailers like Neiman Marcus and Saks Fifth Avenue report strong sales resulting from substantial holiday discounting; catalogue and online retail sales are expected to show strong gains for 2003, due to inclement weather that kept many shoppers at home during holiday season; photo (M)",
#     'web_url': 'https://www.nytimes.com/2003/12/27/business/sales-results-for-the-holiday-trickle-in-and-trickle-up.html',
#     'snippet': "Estimates of Christmas holiday sales gain this year range from 3.5 percent to 5.7 percent over last year's disappointing holiday season; analysts say 2003 sales will be about average for holiday shopping season, rather than above average as many r...",
#     'lead_paragraph': "As sales results began to trickle in yesterday, it became clear that this year's holiday season was only ho-hum for most retailers, far from the one bursting with consumer cheer they had once hoped for.",
#     'print_section': 'C',
#     'print_page': '1',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Sales Results for the Holiday Trickle In and Trickle Up',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Sales Results for the Holiday Trickle In and Trickle Up',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Wal-Mart Stores Inc',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'NEIMAN MARCUS GROUP INC',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Saks Fifth Avenue',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 4, 'major': 'N'},
#      {'name': 'subject', 'value': 'CATALOGUES', 'rank': 5, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 8, 'major': 'N'}],
#     'pub_date': '2003-12-27T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Tracie Rozhon',
#      'person': [{'firstname': 'Tracie',
#        'middlename': None,
#        'lastname': 'Rozhon',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/e43d0e17-e954-5b0b-98c9-5a6ed1db0910',
#     'word_count': 795,
#     'uri': 'nyt://article/e43d0e17-e954-5b0b-98c9-5a6ed1db0910'},
#    {'abstract': 'Estimates of post-Thanksgiving retail sales range from flat to modest, leaving many merchants hoping that things would pick up later in season; some spokesmen comment (M)',
#     'web_url': 'https://www.nytimes.com/2003/12/01/us/early-sales-appear-modest-as-holiday-season-begins.html',
#     'snippet': 'Estimates of post-Thanksgiving retail sales range from flat to modest, leaving many merchants hoping that things would pick up later in season; some spokesmen comment (M)',
#     'lead_paragraph': 'Estimates of post-Thanksgiving retail sales ranged yesterday from flat to modest, leaving many merchants hoping that things would pick up later in the season.',
#     'print_section': 'A',
#     'print_page': '21',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Early Sales Appear Modest As Holiday Season Begins',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Early Sales Appear Modest As Holiday Season Begins',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Sales',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 3, 'major': 'N'}],
#     'pub_date': '2003-12-01T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'National Desk',
#     'section_name': 'U.S.',
#     'byline': {'original': 'By Tracie Rozhon',
#      'person': [{'firstname': 'Tracie',
#        'middlename': None,
#        'lastname': 'Rozhon',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/66ae8b41-3064-5ebd-955e-c77e561bad30',
#     'word_count': 725,
#     'uri': 'nyt://article/66ae8b41-3064-5ebd-955e-c77e561bad30'},
#    {'abstract': 'OfficeMax, the office products retailer, said yesterday that sales this quarter would exceed its expectations after a one-day record of more than $40 million on Friday.     The number of transactions on the day after Thanksgiving set a single-day record, the chief executive, Michael H. Feuer, said.   ',
#     'web_url': 'https://www.nytimes.com/2003/12/02/business/officemax-raises-forecast-for-the-quarter.html',
#     'snippet': '',
#     'lead_paragraph': 'OfficeMax, the office products retailer, said yesterday that sales this quarter would exceed its expectations after a one-day record of more than $40 million on Friday.',
#     'print_section': 'C',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'OfficeMax Raises Forecast for the Quarter',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'OfficeMax Raises Forecast for the Quarter',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2003-12-02T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/750362cb-b9a4-5adb-9d1e-8d965547c1c1',
#     'word_count': 134,
#     'uri': 'nyt://article/750362cb-b9a4-5adb-9d1e-8d965547c1c1'},
#    {'abstract': 'Intel Corp raises low end of its fourth-quarter revenue forecast because of strong holiday sales of its microprocessors for personal computers, but surprises investors with $600 million charge related to acquisition in 1999 of DSP Communications for $1.6 billion (M)',
#     'web_url': 'https://www.nytimes.com/2003/12/05/business/intel-shares-fall-on-news-of-unexpected-write-off.html',
#     'snippet': 'Intel Corp raises low end of its fourth-quarter revenue forecast because of strong holiday sales of its microprocessors for personal computers, but surprises investors with $600 million charge related to acquisition in 1999 of DSP Communications f...',
#     'lead_paragraph': "The Intel Corporation raised the low end of its fourth-quarter revenue forecast yesterday because of strong holiday sales of its microprocessors for PC's, but it surprised investors with a $600 million charge related to an acquisition made four years ago.",
#     'print_section': 'C',
#     'print_page': '3',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Intel Shares Fall on News Of Unexpected Write-Off',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Intel Shares Fall on News Of Unexpected Write-Off',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'DSP COMMUNICATIONS INC',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations', 'value': 'Intel Corp', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Mergers, Acquisitions and Divestitures',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2003-12-05T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Laurie J. Flynn',
#      'person': [{'firstname': 'Laurie',
#        'middlename': 'J.',
#        'lastname': 'Flynn',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/0ca4c3f2-4ee6-5b18-88b3-de851236f575',
#     'word_count': 447,
#     'uri': 'nyt://article/0ca4c3f2-4ee6-5b18-88b3-de851236f575'},
#    {'abstract': 'Keynote Systems reports that 12 popular online retail sites whose performance it tracks moved more slowly and failed more frequently in early December than than they did before Thanksgiving; says some are losing far more than 1 percent of potential holiday sales because of poor performance; graph (M)',
#     'web_url': 'https://www.nytimes.com/2003/12/15/business/e-commerce-report-several-most-popular-online-merchants-have-struggled-cope-with.html',
#     'snippet': 'Keynote Systems reports that 12 popular online retail sites whose performance it tracks moved more slowly and failed more frequently in early December than than they did before Thanksgiving; says some are losing far more than 1 percent of potentia...',
#     'lead_paragraph': 'ONLINE retailers can forget about Black Friday -- the day after Thanksgiving when holiday shoppers overrun conventional stores. For online merchants, the real trouble seems to be early December.',
#     'print_section': 'C',
#     'print_page': '8',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'E-Commerce Report; Several of the most popular online merchants have struggled to cope with heavy holiday traffic, a survey shows.',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'E-Commerce Report; Several of the most popular online merchants have struggled to cope with heavy holiday traffic, a survey shows.',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'KEYNOTE SYSTEMS',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Computers and the Internet',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2003-12-15T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bob Tedeschi',
#      'person': [{'firstname': 'Bob',
#        'middlename': None,
#        'lastname': 'Tedeschi',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/508cc1e6-0563-5061-9803-9585736d73b1',
#     'word_count': 1325,
#     'uri': 'nyt://article/508cc1e6-0563-5061-9803-9585736d73b1'},
#    {'abstract': "Nassau Council of Chambers of Commerce, representing more than 6,000 businesses in Nassau County, NY, calls on residents to patronize local merchants in order to boost county's economy (S)",
#     'web_url': 'https://www.nytimes.com/2003/12/14/nyregion/li-work.html',
#     'snippet': "Nassau Council of Chambers of Commerce, representing more than 6,000 businesses in Nassau County, NY, calls on residents to patronize local merchants in order to boost county's economy (S)",
#     'lead_paragraph': 'Patronize Local Merchants, Nassau Business Group Urges',
#     'print_section': 'LI',
#     'print_page': '14',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'L.I.@WORK',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'L.I.@WORK',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'glocations',
#       'value': 'Nassau County (NY)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'NASSAU COUNCIL OF CHAMBERS OF COMMERCE',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2003-12-14T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Long Island Weekly Desk',
#     'section_name': 'New York',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/24cdb294-0a5f-5458-aad7-9f24b47f1877',
#     'word_count': 349,
#     'uri': 'nyt://article/24cdb294-0a5f-5458-aad7-9f24b47f1877'},
#    {'abstract': 'Interview with specialty retailing anÿ',
#     'web_url': 'https://www.nytimes.com/2003/11/23/business/market-insight-retailers-get-ready-to-gallop-into-the-black.html',
#     'snippet': 'Interview with specialty retailing anÿ',
#     'lead_paragraph': 'THE day after Thanksgiving is known in the retail trade as Black Friday. It is the unofficial start of the holiday buying season, which now stretches to the end of the year.',
#     'print_section': '3',
#     'print_page': '6',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Retailers Get Ready To Gallop Into the Black',
#      'kicker': 'MARKET INSIGHT',
#      'content_kicker': None,
#      'print_headline': 'MARKET INSIGHT; Retailers Get Ready To Gallop Into the Black',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Bear Stearns Cos',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'TELSEY, DANA', 'rank': 2, 'major': 'N'},
#      {'name': 'subject', 'value': 'HOLIDAY TRADE', 'rank': 3, 'major': 'N'},
#      {'name': 'subject', 'value': 'Stocks and Bonds', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '2003-11-23T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Money and Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Kenneth N. Gilpin',
#      'person': [{'firstname': 'Kenneth',
#        'middlename': 'N.',
#        'lastname': 'Gilpin',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Interview',
#     '_id': 'nyt://article/acc7b13f-cede-5479-a39e-1fb22ada47fa',
#     'word_count': 819,
#     'uri': 'nyt://article/acc7b13f-cede-5479-a39e-1fb22ada47fa'},
#    {'abstract': "May Department Stores, owner of Lord & Taylor chain, and TJX Companies, operator of TJ Maxx stores, say third-quarter profit rose; earnings declined at J C Penney; National Retail Federation says overall holiday sales are expected to rise 5.7 percent; J C Penney's net income fell to $80 million from $123 million year earlier; sales in three months ended Oct 25 rose 1.4 percent, to $7.99 billion; May's net income rose to $47 million from $16 million year ago; revenue fell less than 1 percent, to $2.98 billion, in period ended Nov 1; sales at stores open least one year declined 2.4 percent; TJX says net income increased to $182.8 million from $147.4 million; sales rose 11 percent, to $3.39 billion; photo (M)",
#     'web_url': 'https://www.nytimes.com/2003/11/12/business/strong-quarter-at-2-retailers-penney-is-off.html',
#     'snippet': 'May Department Stores, owner of Lord & Taylor chain, and TJX Companies, operator of TJ Maxx stores, say third-quarter profit rose; earnings declined at J C Penney; National Retail Federation says overall holiday sales are expected to rise 5.7 perc...',
#     'lead_paragraph': 'May Department Stores, owner of the Lord & Taylor chain, and TJX Companies, operator of T.J. Maxx stores, said yesterday that third-quarter profits rose. Earnings declined at J.C. Penney, the department store company, because of sluggish drugstore sales.',
#     'print_section': 'C',
#     'print_page': '12',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Strong Quarter at 2 Retailers; Penney Is Off',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Strong Quarter at 2 Retailers; Penney Is Off',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'organizations',
#       'value': 'Penney, J C, Co',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'National Retail Federation',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'TJX COMPANIES',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'May Department Stores Co',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Sales', 'rank': 5, 'major': 'N'},
#      {'name': 'subject', 'value': 'Company Reports', 'rank': 6, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'RETAIL STORES AND TRADE',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Christmas', 'rank': 8, 'major': 'N'}],
#     'pub_date': '2003-11-12T05:00:00+0000',
#     'document_type': 'article',
#     'news_desk': 'Business/Financial Desk',
#     'section_name': 'Business Day',
#     'byline': {'original': 'By Bloomberg News',
#      'person': [{'firstname': 'Bloomberg',
#        'middlename': None,
#        'lastname': 'News',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/5a3b19b6-1635-5c1b-bb4d-3c1c0fc3a74c',
#     'word_count': 413,
#     'uri': 'nyt://article/5a3b19b6-1635-5c1b-bb4d-3c1c0fc3a74c'}],
#   'meta': {'hits': 18, 'offset': 0, 'time': 112}}}
